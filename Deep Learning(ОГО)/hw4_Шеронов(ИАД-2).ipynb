# %% [markdown]
# <center>
# <img src="https://raw.githubusercontent.com/dvgodoy/PyTorch101_ODSC_Europe2020/master/images/linear_dogs.jpg" width="800">
#
# # Основы глубинного обучения: домашнее задание 4
# </center>

# %% [markdown]
# **ФИО:** Шеронов Данил Сергеевич ИАД-2
#
# **Забавный факт о себе:** из деревни.

# %% [markdown]
# ## Общая информация
#
# __Дата выдачи:__ 09.12.2023
#
# __Дедлайн:__ 23:59MSK 18.12.2023
#
# В случае этой домашки мягкий дедлан совпадает с жёстким.

# %% [markdown]
# ## Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 5.2 балла (3 основных балла и ещё 2.2 бонусных).
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import tqdm

# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Описание данных
#
# Данные можно [скачать с гугл-диска.](https://drive.google.com/drive/folders/11oCcLplWtp_qm-WuEbfCFP_Mz5K_z3ps?usp=sharing) Если вы делаете задание в колабе, то строчки ниже сами скачают вам данные.

# %%
import gdown

#url = "https://drive.google.com/drive/folders/11oCcLplWtp_qm-WuEbfCFP_Mz5K_z3ps?usp=sharing"
url = "https://drive.google.com/drive/folders/1w6u7bf310vjGytucfKsAFWJD3ReXXYZw?usp=sharing"

gdown.download_folder(url, quiet=True, use_cookies=False)
# Out:
# ['/content/news_data/out.csv',
#  '/content/news_data/ria_news.tsv',
#  '/content/news_data/vk_comments.tsv',
#  '/content/news_data/vk_news.tsv',
#  '/content/news_data/vk_news2.tsv']

# %% [markdown]
# В таблице `ria_news.tsv`  лежат данные о новостях, вышедших на сайте РИА-НОВОСТИ с 15 марта 2018 года по 31 декабря 2018 года.
#
# - `href` - уникальный идентификатор новости (ссылка на неё)
# - `date` - дата публикации новости
# - `time` - время публикации новости
# - `title` - заголовок новости
# - `snippet` - краткое описание новости
# - `text` - текст новости
# - `category` - категория новости
# - `keywords` - ключевые слова (подкатегории новости)
# - `shows` - счётчик с числом просмотров новости на сайте (на момент парсинга)

# %%
df_ria = pd.read_csv('news_data/ria_news.tsv', sep='\t')
df_ria = df_ria[~df_ria.tags.isnull()]
print(df_ria.shape)
df_ria.head()
# Out:
# (201708, 9)
#                         href        date                    time  \
# 0  /20181231/1548961410.html  2018-12-31  31 декабря 2018, 23:52
# 1  /20181231/1548961364.html  2018-12-31  31 декабря 2018, 23:19
# 2  /20181231/1548961337.html  2018-12-31  31 декабря 2018, 23:12
# 3  /20181231/1548961304.html  2018-12-31  31 декабря 2018, 23:09
# 4  /20181231/1548961265.html  2018-12-31  31 декабря 2018, 23:07
#
#                                                title  \
# 0  Нетаньяху не собирается в отставку в случае пр...
# 1  Макрон в новогоднем обращении затронул тему ре...
# 2  Аарон Рэмзи проведет переговоры с пятью топ-кл...
# 3  Гол Азмуна принес сборной Ирана победу над кат...
# 4  Пятая ракетка мира дель Потро пропустит Открыт...
#
#                                              snippet  \
# 0  Премьер-министр Израиля Биньямин Нетаньяху не ...
# 1  Результат реформ не может быть мгновенным, зая...
# 2  Полузащитник лондонского "Арсенала" Аарон Рэмз...
# 3  Футболисты сборной Ирана одержали победу над к...
# 4  Аргентинский теннисист Хуан Мартин дель Потро ...
#
#                                                 text category  \
# 0  МОСКВА, 31 дек - РИА Новости. Премьер-министр ...   В мире
# 1  ПАРИЖ, 31 дек – РИА Новости. Результат реформ ...   В мире
# 2  МОСКВА, 31 дек - РИА Новости. Полузащитник лон...      NaN
# 3  МОСКВА, 31 дек - РИА Новости. Футболисты сборн...      NaN
# 4  МОСКВА, 31 дек - РИА Новости. Аргентинский тен...      NaN
#
#                                      tags   shows
# 0     Биньямин Нетаньяху, Израиль, В мире   728.0
# 1       Эммануэль Макрон, Франция, В мире  3086.0
# 2                     ФК Арсенал (Лондон)   183.0
# 3  Сердар Азмун, Сборная Ирана по футболу    78.0
# 4                                  Теннис    79.0

# %% [markdown]
# Многие новостные агенства поддерживают странички в социальных сетях. Они постят туда самые сочные сюжеты. В таблице `vk_news.tsv` лежат данные о новостях, которые РИА запостили ВКонтакте в период времени с  `2017-09-29 01:28:55` по `2019-02-01 23:13:17`.
#
# - `id` - уникальный идентификатор поста
# - `href` - ссылка на сайт (если она была указана в посте)
# - `datetime` - дата и время публикации новости
# - `title` - заголовок новости
# - `text` - текст новости в социальной сети
# - `likes` - число лайков под постом
# - `comments` - число комментариев под постом

# %%
df_vk = pd.read_csv('news_data/vk_news.tsv', sep='\t')
df_vk['snippet'] = df_vk['text']
df_vk.drop('text', axis=1, inplace=True)
print(df_vk.shape)
df_vk.head()
# Out:
# (19928, 7)
#          id                       href             datetime  \
# 0  24006362  /20190201/1550280358.html  2019-02-01 23:13:17
# 1  24006240  /20190201/1550268781.html  2019-02-01 22:38:41
# 2  24006100  /20190201/1550282212.html  2019-02-01 21:58:52
# 3  24005972  /20190202/1550283179.html  2019-02-01 21:27:06
# 4  24005764  /20190201/1550262848.html  2019-02-01 20:55:54
#
#                                                title  likes  comments snippet
# 0  В ДНР заявили о задержании диверсантов, причас...     15        28     NaN
# 1  Житель Урала "заминировал" ТЦ из-за снятия  со...     32        42     NaN
# 2      В Черном море нашли "потерянный флот Гитлера"     84        23     NaN
# 3  В США освободили задержанную российскую актрис...     58        35     NaN
# 4  Толкнувший Скабееву депутат Рады заявил о гроз...     45       145     NaN

# %% [markdown]
# В таблице `vk_comments.tsv` лежат комментарии к новостям.
#
# - `id` - уникальный идентификатор комментария
# - `post_id` - идентификатор новости, под которой был оставлен комментарий
# - `datetime` - дата и время, когда был оставлен комментарий
# - `text` - текст комментария
# - `likes` - число лайков под комментарием

# %%
df_comments = pd.read_csv('news_data/vk_comments.tsv', sep='\t')
df_comments = df_comments[~df_comments.text.isnull()]
print(df_comments.shape)
df_comments.head()
# Out:
# <ipython-input-6-9f937a17e540>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_comments = pd.read_csv('news_data/vk_comments.tsv', sep='\t')
# (2612629, 5)
#            id     post_id             datetime  \
# 0  24006366.0  24006362.0  2019-02-01 23:14:14
# 1  24006370.0  24006362.0  2019-02-01 23:15:23
# 2  24006371.0  24006362.0  2019-02-01 23:16:21
# 3  24006374.0  24006362.0  2019-02-01 23:16:38
# 4  24006375.0  24006362.0  2019-02-01 23:16:40
#
#                                                 text  likes
# 0                                       ЧВК Вагнера?    5.0
# 1                [id4710641|Евгений], выздоравливай.    3.0
# 2  [id442655034|Андрей], искренне желаю этого все...    4.0
# 3                         Опять про Украину новости?    1.0
# 4                                      Че такое ДНР?    2.0

# %% [markdown]
# # А что надо сделать то?
#
# В тетрадке вам предстоит сделать следующие шаги:
#
# 1. Вы обучите нейросеть предсказывать категорию новости
# 2. Вы построите предсказания для тех новостей, где мы ничего не знаем о категории
# 3. Вы используете уже обученный для сентимент-анализа классификатор из библиотеки `hugging face` чтобы предсказать эмоциональную окраску каждого комментария
# 4. Вы проведёте аналитику по новостям, а именно построите топы из самых позитивных и негативных категорий и новостей
#
# Для первого шага вам будет дан бэйзлайн. Если вы его прогоните, у вас получится базовая модель, которая даст некоторое качество решения задачи. Вам надо будет выяснить, насколько это качество оказалось хорошим, а затем внести в код некоторые улучшения.

# %% [markdown]
# ## Часть 1: категоризация новостей (1.2 + 2 бонусных балла)
#
# Каждой новости в соотвествие поставлены ключевые слова. Будем считать, что эти ключевые слова — тематики новости. Нужно научиться предсказывать тематики по тексту новости. Готовые тематики у нас есть только по новостям с сайта. Они за 2018 год. По новостям из ВКонтакте у нас тематик нет. Мы собираемся их предсказать.
#
# Новости, опубликованные ВКонтакте, отличаются от новостей с сайта тем, что у них есть только титул и короткое описание. Странно будет обучать нейросеть на длинных текстах, а потом использовать её на коротких описаниях. Мы не будем так делать. Мы попробуем обучить базовый вариант нейронной сети только на заголовках новостей. Все, кто захочет получить бонусные баллы, смогут попробовать добавить в нейросеть сниппеты (так назыают короткие описания новостей).

# %% [markdown]
# ## 1.1 Подготовка таргета
#
# Поработаем с таргетом. Мы будем предсказывать переменную `tags`. Давайте выясним скоько уникальных тегов существует.

# %%
from collections import Counter

# удалим все лишние пробелы и сделаем lowercase
df_ria['tags'] = (
    df_ria.tags.
    apply(lambda w: ','.join([item.strip() for item in  w.lower().split(',')]))
)

tags = ','.join(list(df_ria.tags.values))
tags_cnt = Counter(tags.split(','))

print(len(tags_cnt))
tags_cnt.most_common()[-20:]
# Out:
# 13344
# [('блог анны завершинской об автоспорте - блоги', 1),
#  ('министерство транспорта рб', 1),
#  ('министерство здравоохранения грузии', 1),
#  ('палех', 1),
#  ('юрий посохов (хореограф)', 1),
#  ('мария александрова', 1),
#  ('том бенсон', 1),
#  ('абдул каюм кочай', 1),
#  ('нуман куртулмуш', 1),
#  ('mipim', 1),
#  ('владимир попов', 1),
#  ('брюно женезио', 1),
#  ('роберт фицо', 1),
#  ('сергей пашинский', 1),
#  ('валерия гонтарева', 1),
#  ('нововоронеж', 1),
#  ('императорское православное палестинское общество', 1),
#  ('event_poslanie_prezidenta_rf_federalnomu_sobraniju', 1),
#  ('фхтр', 1),
#  ('игорь честин', 1)]

# %% [markdown]
# Всего в выборке есть порядка 13 000 тэгов. Многие встречаются всего по разу. Давайте оставим в выборке только те тэги, которые встречаются более 30 раз.

# %%
target_tags = {tag for tag,cnt in tags_cnt.most_common() if cnt > 30}
len(target_tags)
# Out:
# 1583

# %% [markdown]
# Закодируем теги для OHE.

# %%
tag2idx = dict(zip(target_tags, range(len(target_tags))))
idx2tag = {jtem: item for item,jtem in tag2idx.items()}

# %% [markdown]
# Почистим таргет от лишних тэгов.

# %%
df_ria['target_tags'] = (
    df_ria.tags.
    apply(lambda w: [tag2idx.get(item) for item in  w.split(',') if item in target_tags])
)

df_ria = df_ria[df_ria.target_tags.apply(len) > 0]
df_ria.shape
# Out:
# (201437, 10)

# %%
df_ria.target_tags.values[:3]
# Out:
# array([list([519, 52, 1237]), list([433, 730, 1237]), list([257])],
#       dtype=object)

# %% [markdown]
# ## 1.2 Подготовка текстов
#
# Теперь займёмся предобработкой текстов. Приведём все слова к маленькому регистру и выбросим мусорные символы. В качестве токенов будем рассматривать отдельные слова.
#
# Напомню, что мы пока что решили работать только с названиями статей. Поэтому вся предобработка применяется исключительно к ним. **Спойлер:** предобработку для сниппетов вы сделаете сами в первом же задании.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re
from nltk.tokenize import word_tokenize

def normalise_text(text):
    text = text.lower()

    # сурово регулярками выкидываем мусорные символы
    text = re.sub('[^а-яa-z0-9 ]', '', text)
    return text.strip()

df_ria['title_clean'] = df_ria.title.apply(normalise_text)

word_cnt = Counter(word_tokenize(' '.join(df_ria.title_clean.values)))
len(word_cnt)
# Out:
# 112178

# %%
word_cnt.most_common()[:10]
# Out:
# [('в', 127323),
#  ('на', 44386),
#  ('с', 26150),
#  ('и', 21771),
#  ('о', 19948),
#  ('по', 17014),
#  ('россии', 13494),
#  ('не', 13483),
#  ('сша', 9942),
#  ('за', 9881)]

# %% [markdown]
# Давайте почистим словарь от стоп-слов и подготовим его к использованию внутри датасета. Мы будем с помощью словаря заменять слова на индексы. Добавим в словарь несколько специальных токенов для неизвестных слов и паддингов.

# %%
from nltk.corpus import stopwords

stops_ru = set(stopwords.words('russian'))
len(stops_ru)
# Out:
# 151

# %%
vocabulary = {
    "#PAD#": 0, "#UNK#": 1
}

k = 2
for word, _ in word_cnt.most_common():
    if word not in stops_ru:
        vocabulary[word] = k
        k += 1

# %%
len(vocabulary)
# Out:
# 112030

# %% [markdown]
# Завернём код для создания словаря в функцию.

# %%
def create_vocab(text, stops_ru=stops_ru):

    word_cnt = Counter(word_tokenize(text))
    vocabulary = {
        "#PAD#": 0, "#UNK#": 1
    }

    k = 2
    for word, _ in word_cnt.most_common():
        if word not in stops_ru:
            vocabulary[word] = k
            k += 1
    return vocabulary

# %% [markdown]
# __[0.2 балла] Задание 1:__
#
# - Cделайте аналогичную предобработку титулов из таблички `df_vk`. Запишите получившийся результат в столбец `title_clean` по аналогии с таблицей `df_ria`.
# - Сделайте для обеих таблиц предобработку колонок со сниппетами `snippet` и запишите получившийся результат в столбец `snippet_clean`. Все пропуски заполните токеном `"#UNK#"`.

# %%
# (your)my code here
# ヽ(♡‿♡)ノ

df_vk['title_clean'] = df_vk.title.apply(normalise_text)

df_ria['snippet_clean'] = df_ria.snippet.apply(lambda text: "#UNK#" if str(text) == 'nan' else normalise_text(text))
df_vk['snippet_clean'] = df_vk.snippet.apply(lambda text: "#UNK#" if str(text) == 'nan' else normalise_text(text))

# %% [markdown]
# ## 1.3 Поставка данных

# %% [markdown]
# Пересечение сайта и ВК по опубликованным новостям довольно маленькое. Мы обучаем модель на данных с сайта. Предсказания мы будем строить на данных из ВК. У этих данных разная природа. В ВК описание статей и заголовки короче. Модель может хорошо показать себя на данных с новостного сайта, но сильно просесть в качестве на данных из ВК.
#
# Давайте сохраним пересечение в отдельную табличку, чтобы на нём можно было понять, насколько сильно деградирует модель.

# %%
ria_hrefs = set(df_ria.href.values)
vk_hrefs = set(df_vk.href.values)
test_hrefs = (vk_hrefs & ria_hrefs)

print('Размер отложенной выборки:', len(test_hrefs))

df = df_ria[~df_ria.href.isin(test_hrefs)]
# Out:
# Размер отложенной выборки: 1128

# %% [markdown]
# По странному совпадению (я правда не знаю почему) пересечение лежит в декабре. Мы будем его использовать как тестовую выборку.

# %%
df_ria[df_ria.href.isin(test_hrefs)].date.min(), df_ria[df_ria.href.isin(test_hrefs)].date.max()
# Out:
# ('2018-12-06', '2018-12-31')

# %% [markdown]
# Предположим, что мы делим выборку на обучающую и тестовую случайно. За один и тот же промежуток времени может выйти довольно большое число новостей с одинаковым заголовком. Давайте представим себе, что в тесте и трэйне есть много статей про одно и то же событие. Модель научилась на обучающей выборке хорошо его тегировать. Остальные события модель тегирует намного хуже. Метрики на тестовой выборке высокие. В следующем месяце СМИ перестают освещать это событие, в потоке новостей совершенно другие новости. Качество модели резко проседает.
#
# Чтобы не напороться на завышенные метрики, обычно выборку дробят на обучающую и тестовую по времени. Тогда статьи из теста будут имитировать поток новых новостей, освещающих новые события.

# %%
df.date.min(), df.date.max()
# Out:
# ('2018-03-15', '2018-12-31')

# %% [markdown]
# __[0.2 балла] Задание 2:__ Разбейте выборку на обучающую, валидационную и тестовую. В тест возьмите весь декабрь. В валидацию октябрь и ноябрь.

# %%
# (your)my code here
# ♡ (´｡• ω •｡`)

df_test = df_ria[df_ria['date'] >= '2018-12-01']
df_val = df_ria[df_ria['date'] >= '2018-10-01'].drop(index=df_test.index)
df_train = df_ria.drop(index=(df_test + df_val).index)

# %%
assert (df_test.shape[0] + df_val.shape[0] + df_train.shape[0]) == df_ria.shape[0]
assert df_test.shape[1] == df_val.shape[1] == df_train.shape[1] == df_ria.shape[1]

# %% [markdown]
# Сформируем отложенную выборку (пересечение ВКонтакте и РИА).

# %%
df_oob = df_vk[df_vk.href.isin(test_hrefs)][['href', 'title_clean']]

df_ria_oob = df_ria[df_ria.href.isin(test_hrefs)][['href', 'target_tags']]
df_oob = df_oob.set_index('href').join(df_ria_oob.set_index('href')).reset_index()
df_oob.head()
# Out:
#                         href  \
# 0  /20181206/1547493936.html
# 1  /20181206/1547516457.html
# 2  /20181206/1547520788.html
# 3  /20181206/1547521406.html
# 4  /20181206/1547522342.html
#
#                                          title_clean   target_tags
# 0  эксперты определили самые бюджетные экзотическ...  [1209, 1559]
# 1  рада приняла закон расширяющий контролируемую ...  [1552, 1237]
# 2  россия оказалась родиной древнейших титанозавр...    [918, 946]
# 3  школа в красноярске превратилась в хогвартс из...        [1502]
# 4  рада решила не продлевать договор о дружбе и с...   [803, 1237]

# %% [markdown]
# Напишем датасет для поставки данных в нейросеть.

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

class NewsDataset(Dataset):

    def __init__(self, target, title, vocab, vocab_size, max_title_len, max_classes, snippet=None, max_snippet_len=None):

        self.vocab = {word: idx  for word,idx in vocab.items() if idx < vocab_size}
        self.max_classes = max_classes
        self.y=self.target_ohe(target)
        self.X_title = self.create_text(title, max_title_len)
        self.X_snippet = snippet
        if snippet is not None:
            self.X_snippet = self.create_text(snippet, max_snippet_len)

    def target_ohe(self, target):
        y = torch.zeros((len(target), self.max_classes))
        for i, t in enumerate(target):
            y[[i]*len(t), t] = 1.0
        return y

    def create_text(self, texts, max_len):
        result = [ ]
        for sent in texts:
            # {#PAD: 0, #UNK: 1}
            sent_tokenize = [self.vocab.get(item, 1) for item in word_tokenize(sent)]

            # приводим все тексты к max_len
            if len(sent_tokenize) >= max_len:
                sent_tokenize = sent_tokenize[:max_len]
            else:
                sent_tokenize += [0] * (max_len - len(sent_tokenize))
            result.append(sent_tokenize)
        return torch.tensor(result, dtype=torch.int)

    def __len__(self):
        return len(self.X_title)

    def __getitem__(self, idx):
        if self.X_snippet is not None:
            return (self.X_title[idx, :], self.y[idx], self.X_snippet[idx, :])
        else:
            return (self.X_title[idx, :], self.y[idx])

# %% [markdown]
# __[0.2 балла] Задание 3:__ Сейчас датасет умеет работать только с полем `title_clean`. Давайте сделаем этот датасет более многофукнциональным и добавим в него возможность добавить в обработку данных сниппет.
#
# 1. Внутри датасета `snippet` надо обработать точно также как и `title`.
# 2. Если `snippet=None`, датасет должен вернуть два объекта: `X_title, y`. В обратном случае датасет должен вернуть три объекта.
#
# **Важно:** Весь код ниже работает сейчас без сниппета. Он не должен развалиться от того, что сниппет в нём нигде не указан.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

# Внесите в код датасета выше свои правки

# внёс.

# %% [markdown]
# Объявим датасеты, оставим в словаре 30 000 самых частотных слов. Будем смотреть на титулы максимальной длины 20.

# %%
CLASSES_NUM = len(idx2tag)
VOCAB_SIZE = 10000
MAX_TITLE_LEN = 20

# словарь создаем по всей выборке
vocabulary = create_vocab(' '.join(df_ria.title_clean.values))

# объявляем датасеты
train_dataset = NewsDataset(df_train.target_tags.values, df_train.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM )
val_dataset = NewsDataset(df_val.target_tags.values, df_val.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM )
test_dataset = NewsDataset(df_test.target_tags.values, df_test.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM )

# %%
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=64, num_workers=2)
val_dataloader = DataLoader(val_dataset, shuffle=False, batch_size=4096, num_workers=2)

# %% [markdown]
# ## 1.4 Архитектуры
#
# Соберём базовую архитектуру для обучения.

# %%
from torch import nn
import torch.nn.functional as F

class SimpleClassifier(nn.Module):

    def __init__(self, vocab_size, embedding_dim, output_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.fc = nn.Linear(embedding_dim, output_dim)

    def forward(self, title):
        embedded = self.embedding(title)
        embedded = embedded.mean(dim=1)
        return self.fc(embedded)

# %% [markdown]
# Соберём в `pytorch_lightning` модуль для обучения нейронки.

# %%
# !pip3 install pytorch_lightning
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.23.5)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.2.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (0.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch_lightning) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.0->pytorch_lightning) (1.3.0)

# %%
import pytorch_lightning as pl

class TrainLightningModule(pl.LightningModule):
    def __init__(self, model, learning_rate, criterion):
        super().__init__()
        self.model = model
        self.criterion = criterion
        self.learning_rate = learning_rate

    def forward(self, title):
        result = self.model(title)
        return result

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
        return optimizer

    def training_step(self, train_batch, batch_idx):
        title, target = train_batch
        logits = self.model(title)
        loss = self.criterion(logits, target)
        self.log(
            "train_loss", loss, prog_bar=True
        )
        return loss

    def validation_step(self, val_batch, batch_idx):
        title, target = val_batch
        logits = self.model(title)
        loss = self.criterion(logits, target)
        self.log(
            "val_loss", loss, prog_bar=True
        )
        return loss

# %% [markdown]
# Обучим модель.

# %%
# !pip install wandb

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from pytorch_lightning.loggers import WandbLogger

# %%
wandb_logger = WandbLogger(project='news')

EMBEDDING_DIM = 300
EPOCHS = 5
LR = 1e-3

model_baseline = SimpleClassifier(VOCAB_SIZE, EMBEDDING_DIM, CLASSES_NUM)
criterion = torch.nn.CrossEntropyLoss()

train_module =TrainLightningModule(model_baseline, LR, criterion)

trainer = pl.Trainer(accelerator="auto", max_epochs=EPOCHS)#, logger=wandb_logger)
trainer.fit(train_module, train_dataloader, val_dataloader)

wandb.finish()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | model     | SimpleClassifier | 3.5 M
# 1 | criterion | CrossEntropyLoss | 0
# -----------------------------------------------
# 3.5 M     Trainable params
# 0         Non-trainable params
# 3.5 M     Total params
# 13.906    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.

# %% [markdown]
# __[0.2 балла] Задание 4:__  Модель выше работает только с титулом.
#
# - Залоггируйте её обучение на [WandB](https://wandb.ai/).
# - Соберите архитектуру, которая будет принимать на вход не только титул, но ещё и сниппет. В этой архитектуре должно происходить следующее:
#
# 1. Общий слой `nn.Embedding` применяется к сниппету и титулу параллельно.
# 2. Происходит усреднее по текстам.
# 3. Вектора конкатятся в один длины 600
# 4. Линейный слой делает классификацию
#
# Обучите эту модель. Сравните траектории обучения на WandB. Прикрепите ссылку на дашборд либо скришот к тетрадке.
#
# Даталоадеры придётся объявить заново с учётом сниппетов. Правда ли, что она бьёт на валидационной выборке модель, обученную только на титулах статей?

# %%
# (your)my code here
# (￢_￢)

CLASSES_NUM = len(idx2tag)
VOCAB_SIZE = 10000
MAX_TITLE_LEN = 20
MAX_SNIPPET_LEN = 333

# словарь создаем по всей выборке
vocabulary = create_vocab(' '.join(df_ria.title_clean.values) + ' ' + ' '.join(df_ria.snippet_clean.values))

# объявляем датасеты
train_dataset = NewsDataset(df_train.target_tags.values, df_train.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM, df_train.snippet_clean.values, MAX_SNIPPET_LEN)
val_dataset = NewsDataset(df_val.target_tags.values, df_val.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM, df_val.snippet_clean.values, MAX_SNIPPET_LEN)
test_dataset = NewsDataset(df_test.target_tags.values, df_test.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM, df_test.snippet_clean.values, MAX_SNIPPET_LEN)

train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=64, num_workers=2)
val_dataloader = DataLoader(val_dataset, shuffle=False, batch_size=512, num_workers=2)

# %%
class SimpleClassifier_v2(nn.Module):

    def __init__(self, vocab_size, embedding_dim, output_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.fc = nn.Linear(2*embedding_dim, output_dim)

    def forward(self, title, snippet):
        title_embedded = self.embedding(title).mean(dim=1)
        snippet_embedded = self.embedding(snippet).mean(dim=1)
        embedded = torch.cat((title_embedded, snippet_embedded), 1)
        return self.fc(embedded)

# %%
class TrainLightningModule_v2(pl.LightningModule):
    def __init__(self, model, learning_rate, criterion):
        super().__init__()
        self.model = model
        self.criterion = criterion
        self.learning_rate = learning_rate

    def forward(self, title, snippet):
        result = self.model(title, snippet)
        return result

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
        return optimizer

    def training_step(self, train_batch, batch_idx):
        title, target, snippet = train_batch
        logits = self.model(title, snippet)
        loss = self.criterion(logits, target)
        self.log(
            "train_loss", loss, prog_bar=True
        )
        return loss

    def validation_step(self, val_batch, batch_idx):
        title, target, snippet = val_batch
        logits = self.model(title, snippet)
        loss = self.criterion(logits, target)
        self.log(
            "val_loss", loss, prog_bar=True
        )
        return loss

# %%
wandb_logger = WandbLogger(project='news')

EMBEDDING_DIM = 300
EPOCHS = 5
LR = 1e-3

model_with_snippet = SimpleClassifier_v2(VOCAB_SIZE, EMBEDDING_DIM, CLASSES_NUM)
criterion = torch.nn.CrossEntropyLoss()

train_module_v2 = TrainLightningModule_v2(model_with_snippet, LR, criterion)

trainer = pl.Trainer(accelerator="auto", max_epochs=EPOCHS, logger=wandb_logger)
trainer.fit(train_module_v2, train_dataloader, val_dataloader)

wandb.finish()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# wandb: Currently logged in as: sheron4ik. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>./wandb/run-20231218_115138-x00e4xus</code>
# Syncing run <strong><a href='https://wandb.ai/sheron4ik/news/runs/x00e4xus' target="_blank">golden-terrain-2</a></strong> to <a href='https://wandb.ai/sheron4ik/news' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/sheron4ik/news' target="_blank">https://wandb.ai/sheron4ik/news</a>
#  View run at <a href='https://wandb.ai/sheron4ik/news/runs/x00e4xus' target="_blank">https://wandb.ai/sheron4ik/news/runs/x00e4xus</a>
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type                | Params
# --------------------------------------------------
# 0 | model     | SimpleClassifier_v2 | 4.0 M
# 1 | criterion | CrossEntropyLoss    | 0
# --------------------------------------------------
# 4.0 M     Trainable params
# 0         Non-trainable params
# 4.0 M     Total params
# 15.806    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# VBox(children=(Label(value='0.001 MB of 0.011 MB uploaded\r'), FloatProgress(value=0.10551289793805539, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆████████</td></tr><tr><td>train_loss</td><td>▇▇▆█▄▅▆▆▄▄▄▄▅▃▄▃▄▁▃▃▂▃▄▂▂▂▂▂▂▃▂▁▁▂▂▁▁▁▂▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_loss</td><td>9.78702</td></tr><tr><td>trainer/global_step</td><td>10694</td></tr><tr><td>val_loss</td><td>11.45582</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-terrain-2</strong> at: <a href='https://wandb.ai/sheron4ik/news/runs/x00e4xus' target="_blank">https://wandb.ai/sheron4ik/news/runs/x00e4xus</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231218_115138-x00e4xus/logs</code>

# %% [markdown]
# [ссылка wandb](https://wandb.ai/sheron4ik/news)
#
# Траектория обучения схожая, но на валидации результаты лучше у baseline (модели без сниппетов).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.5 Инференс и оценка качества моделей
#
# Для каждой новости нам надо предсказывать несколько тэгов. То есть в нашем случае настоящее значение таргета это множество из тэгов $y_i = [tag1, tag2, tag3]$. Прогноз модели также множество из тэгов $\hat y_i = [tag1, tag4]$.
#
# Будем считать метрики качества следующим образом (под $|A|$ имеется в виду мощность множества, то есть число элементов в нём):
#
# $$
# Precision = \frac{1}{n} \sum_{i = 1}^n \frac{|y_i \cap \hat{y}_i|}{|\hat{y}_i|}
# $$
#
# $$
# Recall = \frac{1}{n} \sum_{i = 1}^n \frac{|y_i \cap \hat{y}_i|}{|y_i|}
# $$
#
# Также можно считать аналог Accuracy, но это не самая удачная идея, так как у нас в выборке огромное число нулей и эта метрика при любом разумном пороге для принятия решения будет очень высокой.
#
# $$
# Exact Match = \frac{1}{n} \cdot \frac{1}{k} \sum_{i = 1}^n \sum_{k=1}^K [y_{ij} = \hat{y}_{ij}]
# $$

# %%
def precision(target, y_pred):
    num = ((y_pred == 1) & (target == 1)).sum(dim=1)
    denum = (y_pred == 1).sum(dim=1)
    return (num/(denum + 1e-5)).mean().item()

def recall(target, y_pred):
    num = ((y_pred == 1) & (target == 1)).sum(dim=1)
    denum = (target == 1).sum(dim=1)
    return (num/(denum + 1e-5)).mean().item()

def exact_match(target, y_pred):
    return (1.*(y_pred == target)).mean().item()

# %% [markdown]
# Построим прогноз на тестовой выборке.

# %%
test_dataloader = DataLoader(test_dataset, shuffle=False, batch_size=test_dataset.__len__())

for title, target in test_dataloader:
    logit = model_baseline(title)
    pred_prob = F.softmax(logit, dim=1)

assert pred_prob.shape[0] == test_dataset.__len__()

# %% [markdown]
# Теперь выбирая различное значение порога, мы можем получать разные предсказания. Если взять очень большое значение порога, то метрики сильно просядут, так как во многих документах никакого прогноза не будет построено вообще.

# %%
TRESHOLD = 0.01
y_pred = 1*(pred_prob > TRESHOLD)

print('Exact Match:', exact_match(target, y_pred))
print('Precision:', precision(target, y_pred))
print('Recall:', recall(target, y_pred))
# Out:
# Exact Match: 0.9954971075057983
# Precision: 0.28661131858825684
# Recall: 0.7621862292289734

# %%
TRESHOLD = 0.05
y_pred = 1*(pred_prob > TRESHOLD)
print('Exact Match:', exact_match(target, y_pred))
print('Precision:', precision(target, y_pred))
print('Recall:', recall(target, y_pred))
# Out:
# Exact Match: 0.9983159899711609
# Precision: 0.5167973637580872
# Recall: 0.620395839214325

# %%
TRESHOLD = 0.9
y_pred = 1*(pred_prob > TRESHOLD)

print('Exact Match:', exact_match(target, y_pred))
print('Precision:', precision(target, y_pred))
print('Recall:', recall(target, y_pred))
# Out:
# Exact Match: 0.9983211159706116
# Precision: 0.0053510540165007114
# Recall: 0.004772142041474581

# %% [markdown]
# Дальше мы будем строить довольно много прогнозов. Давайте напишем код для их строительства в виде функции. Обратите внимание, что на модели со снипетом она упадёт. Когда вы доберётесь до строительства прогнозов, функцию придётся немного модернизировать.

# %%
def get_predict(model, dataset):
    dataloader = DataLoader(dataset, shuffle=False, batch_size=dataset.__len__())

    for title, target in dataloader:
        logit = model(title)
        pred_prob = F.softmax(logit, dim=1)

    assert pred_prob.shape[0] == dataset.__len__()
    return pred_prob, target

# %% [markdown]
# __[0.2 балла] Задание 5:__ Какая метрика для нас в этой задаче важнее? Точность или полнота? Почему?
#
# __ваш ответ:__ Точность, потому что нам важно как можно правильнее предсказывать тег(теги) для новости, пусть и не все (но зато правильно), чем находить их все. Потому что, когда модель будет находить их все, вероятнее всего, она также будет находить немалое количество "посторонних" тегов, что будет обманом для новости. (для хайпа важна полнота, конечно же :), но для новостей, всё же, точность).
#
# Лучше оказалась модель без сниппетов

# %% [markdown]
# - Напишите функцию, которая будет подбирать оптимальное значение порога, оптимизирующее выбранную вами метрику.
# - Подберите значение порога на валидационной выборке.
# - Сравните модель со сниппетами и без сниппетов, используя выбранную вами метрику при оптимальном значении порога на тестовой выборке.
# - Какая из них оказалась лучше?

# %%
# (your)my code here
# (＠_＠)
def get_treshold(model, dataset):
    pred_prob, target = get_predict(model, dataset)
    best_treshold, best_metric = 0, 0
    for treshold in np.arange(0, 1, 0.01):
        y_pred = 1*(pred_prob > treshold)
        metric = precision(target, y_pred)
        if metric > best_metric:
            best_treshold = treshold
            best_metric = metric
    return best_treshold, best_metric

# %%
with torch.no_grad():
    best_treshold, best_metric = get_treshold(model_baseline, val_dataset)
    best_treshold, best_metric
# Out:
# (0.12, 0.7260304689407349)

# %%
with torch.no_grad():
    pred_prob, target = get_predict(model_baseline, test_dataset)
    y_pred = 1*(pred_prob > best_treshold)
    print('Precision for model_baseline:', precision(target, y_pred))
# Out:
# Precision for model_baseline: 0.5791546106338501

# %% [markdown]
# __[0.2 балла] Задание 6:__  Постройте прогнозы для отложенной выборки, которая представляет из себя пересечение сайта РИА-новостей и ВКонтакте. Проседает ли на ней качество модели? Насколько сильно?
#
# __ответ:__ проседает, но совершенно незначительно, было ожидаемо

# %%
with torch.no_grad():
    intersection_dataset = NewsDataset(df_oob.target_tags.values, df_oob.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM)
    pred_prob, target = get_predict(model_baseline, intersection_dataset)
    y_pred = 1*(pred_prob > best_treshold)
    print('Precision of intersection dataset:', precision(target, y_pred))
# Out:
# Precision of intersection dataset: 0.5521883368492126

# %%
df_oob.head()
# Out:
#                         href  \
# 0  /20181206/1547493936.html
# 1  /20181206/1547516457.html
# 2  /20181206/1547520788.html
# 3  /20181206/1547521406.html
# 4  /20181206/1547522342.html
#
#                                          title_clean  target_tags
# 0  эксперты определили самые бюджетные экзотическ...  [785, 1135]
# 1  рада приняла закон расширяющий контролируемую ...   [429, 937]
# 2  россия оказалась родиной древнейших титанозавр...  [800, 1578]
# 3  школа в красноярске превратилась в хогвартс из...        [841]
# 4  рада решила не продлевать договор о дружбе и с...   [748, 937]

# %%
# your code here
# (❍ᴥ❍ʋ)

# %% [markdown]
# ## 1.6 Бонусное задание
#
# Давайте модернизируем наши архитектуры настолько, насколько это возможно.
#
# __[0.5 балла]__ Попробуйте собрать более большую архитектуру. Например, сразу после слоя эмбеддингов вы можете попробовать добавить свёрточные слои (`Conv1D` свёртки). Поиграйте с оптимизатором и тп.
#
# Опишите результаты своих экспериментов ниже. Расскажите, что конкретно вы делали и удалось ли вам улучшить качество модели. Все траектории обучения залоггируйте на WandB.

# %% [markdown]
# __Ваш лог экспериментов:__
#
# -
# -
# -

# %%
# your code here
# (⊙_⊙)

# %% [markdown]
# __[0.5]__ Скачайте с сайта [Rusvectores](https://rusvectores.org/ru/models/) любые новостные word2vec эмбединги. Возьмите из модели эмбеддинги для всех слов, которые встречаются вв вашем словаре и добавьте их в модель первым слоем. Заморозьте этот слой и не обновляйте в нём веса. Если у вас в словаре есть слово, но его нет среди предобученных эмбеддингов, замените его на токен `#UNKN`.

# %% [markdown]
# __Ваш лог экспериментов:__
#
# -
# -
# -

# %%
# your code here
# =^･ｪ･^=

# %% [markdown]
# __[1 балл]__ Зафайнтьюньте трансформер для решения задачи с помощью библиотеки `hugging face`. Выбор предобученной модели кратко обоснуйте.

# %% [markdown]
# __Ваш лог экспериментов:__
#
# -
# -
# -

# %%
# your code here
# ٩(ˊ〇ˋ*)و

# %% [markdown]
# Сравните все обученные модели между собой на тестовой выборке.

# %%
# your code here
# (⌐■_■)

# %% [markdown]
# ## Часть 2: предсказание категорий (0.3 балла)
#
# Возьмите датасет `df_vk` и для всех новостей из него предскажите категории с помощью лучшей, получившейся у вас модели.

# %%
#df_vk['target_tags'] = [[0]]*df_vk.shape[0] -- сам заполню

# (your)my code here
# (っ˘ڡ˘ς)
with torch.no_grad():
    vk_dataset = NewsDataset(df_vk.target_tags.values, df_vk.title_clean.values, vocabulary, VOCAB_SIZE, MAX_TITLE_LEN, CLASSES_NUM)
    vk_dataloader = DataLoader(vk_dataset, shuffle=False, batch_size=vk_dataset.__len__())

    title, _ = next(iter(vk_dataloader))
    preds = model_baseline(title)

target_tags, tags = [[] for _ in range(df_vk.shape[0])], [[] for _ in range(df_vk.shape[0])]
for df_idx, tag_idx in (preds > best_treshold).nonzero():
    target_tags[df_idx].append(int(tag_idx))
    tags[df_idx].append(idx2tag.get(int(tag_idx), '#UNK#'))

df_vk['target_tags'] = target_tags
df_vk['tags'] = tags

df_vk.head()
# Out:
#          id                       href             datetime  \
# 0  24006362  /20190201/1550280358.html  2019-02-01 23:13:17
# 1  24006240  /20190201/1550268781.html  2019-02-01 22:38:41
# 2  24006100  /20190201/1550282212.html  2019-02-01 21:58:52
# 3  24005972  /20190202/1550283179.html  2019-02-01 21:27:06
# 4  24005764  /20190201/1550262848.html  2019-02-01 20:55:54
#
#                                                title  likes  comments snippet  \
# 0  В ДНР заявили о задержании диверсантов, причас...     15        28     NaN
# 1  Житель Урала "заминировал" ТЦ из-за снятия  со...     32        42     NaN
# 2      В Черном море нашли "потерянный флот Гитлера"     84        23     NaN
# 3  В США освободили задержанную российскую актрис...     58        35     NaN
# 4  Толкнувший Скабееву депутат Рады заявил о гроз...     45       145     NaN
#
#                                          title_clean snippet_clean  \
# 0  в днр заявили о задержании диверсантов причаст...         #UNK#
# 1  житель урала заминировал тц изза снятия  сотов...         #UNK#
# 2        в черном море нашли потерянный флот гитлера         #UNK#
# 3  в сша освободили задержанную российскую актрис...         #UNK#
# 4  толкнувший скабееву депутат рады заявил о гроз...         #UNK#
#
#                                          target_tags  \
# 0  [0, 3, 17, 28, 33, 38, 56, 72, 96, 101, 119, 1...
# 1  [3, 6, 9, 11, 15, 18, 31, 42, 46, 50, 53, 58, ...
# 2  [3, 22, 56, 101, 109, 157, 210, 231, 239, 242,...
# 3  [3, 7, 15, 35, 47, 78, 87, 109, 116, 124, 144,...
# 4  [3, 33, 87, 96, 101, 116, 134, 142, 157, 167, ...
#
#                                                 tags
# 0  [ливан, туризм, донецк (донецкая область), кип...
# 1  [туризм, тюмень, орловская область, федеральна...
# 2  [туризм, spacex, день победы - 2018, петр поро...
# 3  [туризм, выход сша из ядерной сделки по ирану,...
# 4  [туризм, львовская область, сергей лавров, але...

# %% [markdown]
# На всякий случай сохраните табличку с получившимися у вас предсказаниями. Мало ли, вы не доделаете последнее задание, а потом захотите вернуться к нему. Не прогонять же обучение нейросети и инференс по второму кругу...

# %%
# Ваш код с сохранением данных

# (your)my code here
# ¯\_(ツ)_/¯
df_vk.to_csv('vk_news2.tsv')

# %% [markdown]
# ## Часть 3: сентимент-классификатор (0.5 балла)

# %% [markdown]
# В этой части тетрадки нам предстоит прогнать все комментарии из ВК через сентимент-классификатор. Мы будем делать это с помощью библиотеки HuggingFace. В ней есть удобная [функциональность pipline,](https://huggingface.co/docs/transformers/pipeline_tutorial) чтобы прогонять на своих данных уже обученные модели. 🤗🤗🤗

# %%
df_comments.head()
# Out:
#            id     post_id             datetime  \
# 0  24006366.0  24006362.0  2019-02-01 23:14:14
# 1  24006370.0  24006362.0  2019-02-01 23:15:23
# 2  24006371.0  24006362.0  2019-02-01 23:16:21
# 3  24006374.0  24006362.0  2019-02-01 23:16:38
# 4  24006375.0  24006362.0  2019-02-01 23:16:40
#
#                                                 text  likes
# 0                                       ЧВК Вагнера?    5.0
# 1                [id4710641|Евгений], выздоравливай.    3.0
# 2  [id442655034|Андрей], искренне желаю этого все...    4.0
# 3                         Опять про Украину новости?    1.0
# 4                                      Че такое ДНР?    2.0

# %% [markdown]
# Для классификации комментариев на позитивные, негативные и нейтральные будем использовать [модель, о которой можно почитать по ссылке](https://huggingface.co/seara/rubert-tiny2-russian-sentiment)
#
# Ответьте на следующие вопросы:
#
# 1. Как зовут автора модели?
# 2. Как выглядит архитектура модели? Насколько модель большая?
# 3. На каких данных обучена модель? Адекватно ли использовать её для классификации комментариев ВК?

# %% [markdown]
# Установим библиотеку. 🤗🤗🤗

# %%
# !pip3 install transformers

# %% [markdown]
# Разберитесь как можно прогнать модель на корпусе комментариев и сделайте это. Да, с помощью pipeline можно запустить довольно сложные модели, обученные другими людьми в пару строчек. При объявлении модели не забудьте положить её на нужный `device` 🤗🤗🤗

# %%
# (your)my code here
# ʕ•ᴥ•ʔ
from transformers import pipeline

rubert_tiny2_model = pipeline(model="seara/rubert-tiny2-russian-sentiment", device=device)
sentiment_result = rubert_tiny2_model(df_comments.text.tolist()[:1000])
sentiment_result
# Out:
# [{'label': 'neutral', 'score': 0.9122462868690491},
#  {'label': 'neutral', 'score': 0.8793703317642212},
#  {'label': 'positive', 'score': 0.6762610673904419},
#  {'label': 'neutral', 'score': 0.9259392023086548},
#  {'label': 'neutral', 'score': 0.866222620010376},
#  {'label': 'neutral', 'score': 0.8428511023521423},
#  {'label': 'neutral', 'score': 0.9245758056640625},
#  {'label': 'neutral', 'score': 0.9119594693183899},
#  {'label': 'neutral', 'score': 0.7873875498771667},
#  {'label': 'neutral', 'score': 0.8837028741836548},
#  {'label': 'neutral', 'score': 0.892345666885376},
#  {'label': 'neutral', 'score': 0.8507295250892639},
#  {'label': 'neutral', 'score': 0.8434336185455322},
#  {'label': 'neutral', 'score': 0.5309109091758728},
#  {'label': 'negative', 'score': 0.7910668253898621},
#  {'label': 'neutral', 'score': 0.7685766816139221},
#  {'label': 'negative', 'score': 0.5791840553283691},
#  {'label': 'negative', 'score': 0.899648904800415},
#  {'label': 'neutral', 'score': 0.8236954808235168},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'neutral', 'score': 0.549464762210846},
#  {'label': 'positive', 'score': 0.6592490077018738},
#  {'label': 'neutral', 'score': 0.7513027191162109},
#  {'label': 'neutral', 'score': 0.909001350402832},
#  {'label': 'neutral', 'score': 0.9048395156860352},
#  {'label': 'neutral', 'score': 0.9131532311439514},
#  {'label': 'negative', 'score': 0.48280635476112366},
#  {'label': 'neutral', 'score': 0.6389240622520447},
#  {'label': 'neutral', 'score': 0.6715477705001831},
#  {'label': 'neutral', 'score': 0.8891494274139404},
#  {'label': 'neutral', 'score': 0.7842920422554016},
#  {'label': 'neutral', 'score': 0.6099942326545715},
#  {'label': 'negative', 'score': 0.8992642164230347},
#  {'label': 'neutral', 'score': 0.8904245495796204},
#  {'label': 'neutral', 'score': 0.8371129631996155},
#  {'label': 'negative', 'score': 0.7473187446594238},
#  {'label': 'negative', 'score': 0.5190825462341309},
#  {'label': 'negative', 'score': 0.655584454536438},
#  {'label': 'neutral', 'score': 0.8236954808235168},
#  {'label': 'neutral', 'score': 0.9373692274093628},
#  {'label': 'neutral', 'score': 0.7175542116165161},
#  {'label': 'neutral', 'score': 0.7176331281661987},
#  {'label': 'neutral', 'score': 0.892345666885376},
#  {'label': 'neutral', 'score': 0.8184612393379211},
#  {'label': 'neutral', 'score': 0.875907838344574},
#  {'label': 'negative', 'score': 0.6083706617355347},
#  {'label': 'negative', 'score': 0.6960223317146301},
#  {'label': 'positive', 'score': 0.9512522220611572},
#  {'label': 'neutral', 'score': 0.6700862050056458},
#  {'label': 'neutral', 'score': 0.5211043953895569},
#  {'label': 'negative', 'score': 0.7598165273666382},
#  {'label': 'neutral', 'score': 0.7682715058326721},
#  {'label': 'neutral', 'score': 0.9015563726425171},
#  {'label': 'neutral', 'score': 0.6656677722930908},
#  {'label': 'neutral', 'score': 0.7145341634750366},
#  {'label': 'negative', 'score': 0.4756346642971039},
#  {'label': 'negative', 'score': 0.7765113115310669},
#  {'label': 'neutral', 'score': 0.9054029583930969},
#  {'label': 'neutral', 'score': 0.7014835476875305},
#  {'label': 'neutral', 'score': 0.4959415793418884},
#  {'label': 'negative', 'score': 0.7187689542770386},
#  {'label': 'negative', 'score': 0.4866064786911011},
#  {'label': 'neutral', 'score': 0.9145535230636597},
#  {'label': 'negative', 'score': 0.713150143623352},
#  {'label': 'negative', 'score': 0.7301580905914307},
#  {'label': 'neutral', 'score': 0.5226459503173828},
#  {'label': 'neutral', 'score': 0.5770736336708069},
#  {'label': 'neutral', 'score': 0.7323978543281555},
#  {'label': 'neutral', 'score': 0.6426776647567749},
#  {'label': 'negative', 'score': 0.7325522303581238},
#  {'label': 'neutral', 'score': 0.5779317021369934},
#  {'label': 'positive', 'score': 0.9693044424057007},
#  {'label': 'neutral', 'score': 0.9430086612701416},
#  {'label': 'neutral', 'score': 0.723537266254425},
#  {'label': 'negative', 'score': 0.744418203830719},
#  {'label': 'neutral', 'score': 0.8559884428977966},
#  {'label': 'negative', 'score': 0.510353147983551},
#  {'label': 'neutral', 'score': 0.6873571276664734},
#  {'label': 'neutral', 'score': 0.850570797920227},
#  {'label': 'negative', 'score': 0.7287440896034241},
#  {'label': 'neutral', 'score': 0.7513373494148254},
#  {'label': 'neutral', 'score': 0.7871915102005005},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'neutral', 'score': 0.6551046371459961},
#  {'label': 'positive', 'score': 0.8124315738677979},
#  {'label': 'neutral', 'score': 0.5050806999206543},
#  {'label': 'neutral', 'score': 0.6087138652801514},
#  {'label': 'neutral', 'score': 0.8009026646614075},
#  {'label': 'neutral', 'score': 0.666233241558075},
#  {'label': 'negative', 'score': 0.7363718152046204},
#  {'label': 'neutral', 'score': 0.5637458562850952},
#  {'label': 'neutral', 'score': 0.5125783085823059},
#  {'label': 'neutral', 'score': 0.9355080127716064},
#  {'label': 'neutral', 'score': 0.944866418838501},
#  {'label': 'neutral', 'score': 0.6856750249862671},
#  {'label': 'neutral', 'score': 0.6111539006233215},
#  {'label': 'negative', 'score': 0.42424139380455017},
#  {'label': 'positive', 'score': 0.9935867786407471},
#  {'label': 'neutral', 'score': 0.7965761423110962},
#  {'label': 'neutral', 'score': 0.6236967444419861},
#  {'label': 'neutral', 'score': 0.806313157081604},
#  {'label': 'neutral', 'score': 0.523430347442627},
#  {'label': 'positive', 'score': 0.8198006749153137},
#  {'label': 'neutral', 'score': 0.8446396589279175},
#  {'label': 'neutral', 'score': 0.59304279088974},
#  {'label': 'positive', 'score': 0.9138286709785461},
#  {'label': 'negative', 'score': 0.7794438600540161},
#  {'label': 'neutral', 'score': 0.835629403591156},
#  {'label': 'neutral', 'score': 0.48457071185112},
#  {'label': 'neutral', 'score': 0.7003747224807739},
#  {'label': 'negative', 'score': 0.8452433943748474},
#  {'label': 'neutral', 'score': 0.5568559169769287},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'neutral', 'score': 0.9036970138549805},
#  {'label': 'neutral', 'score': 0.7384815216064453},
#  {'label': 'neutral', 'score': 0.903527557849884},
#  {'label': 'neutral', 'score': 0.8768523335456848},
#  {'label': 'negative', 'score': 0.6447828412055969},
#  {'label': 'neutral', 'score': 0.5205555558204651},
#  {'label': 'negative', 'score': 0.6044209003448486},
#  {'label': 'neutral', 'score': 0.6463110446929932},
#  {'label': 'negative', 'score': 0.5083935260772705},
#  {'label': 'neutral', 'score': 0.5717865824699402},
#  {'label': 'neutral', 'score': 0.8371290564537048},
#  {'label': 'neutral', 'score': 0.6635867357254028},
#  {'label': 'neutral', 'score': 0.8149113655090332},
#  {'label': 'neutral', 'score': 0.7598181366920471},
#  {'label': 'neutral', 'score': 0.6296117305755615},
#  {'label': 'negative', 'score': 0.7912401556968689},
#  {'label': 'negative', 'score': 0.5273334980010986},
#  {'label': 'neutral', 'score': 0.9072049856185913},
#  {'label': 'neutral', 'score': 0.5071023106575012},
#  {'label': 'negative', 'score': 0.7001950144767761},
#  {'label': 'negative', 'score': 0.7925256490707397},
#  {'label': 'neutral', 'score': 0.8957297801971436},
#  {'label': 'negative', 'score': 0.7220728397369385},
#  {'label': 'positive', 'score': 0.7586574554443359},
#  {'label': 'neutral', 'score': 0.5835822820663452},
#  {'label': 'neutral', 'score': 0.8740074634552002},
#  {'label': 'neutral', 'score': 0.7150499224662781},
#  {'label': 'neutral', 'score': 0.7367175221443176},
#  {'label': 'positive', 'score': 0.639224112033844},
#  {'label': 'neutral', 'score': 0.5974610447883606},
#  {'label': 'neutral', 'score': 0.9189893007278442},
#  {'label': 'neutral', 'score': 0.8416463136672974},
#  {'label': 'negative', 'score': 0.711753785610199},
#  {'label': 'neutral', 'score': 0.6678194999694824},
#  {'label': 'neutral', 'score': 0.9007936716079712},
#  {'label': 'neutral', 'score': 0.7696588635444641},
#  {'label': 'negative', 'score': 0.5569401979446411},
#  {'label': 'neutral', 'score': 0.6955269575119019},
#  {'label': 'negative', 'score': 0.8759221434593201},
#  {'label': 'positive', 'score': 0.5622672438621521},
#  {'label': 'neutral', 'score': 0.8267788887023926},
#  {'label': 'neutral', 'score': 0.927264928817749},
#  {'label': 'neutral', 'score': 0.5289487838745117},
#  {'label': 'neutral', 'score': 0.7354059219360352},
#  {'label': 'neutral', 'score': 0.8606919646263123},
#  {'label': 'neutral', 'score': 0.809636116027832},
#  {'label': 'negative', 'score': 0.8859068155288696},
#  {'label': 'neutral', 'score': 0.8452938199043274},
#  {'label': 'neutral', 'score': 0.8095299005508423},
#  {'label': 'neutral', 'score': 0.9513887763023376},
#  {'label': 'neutral', 'score': 0.7416477799415588},
#  {'label': 'neutral', 'score': 0.4989416301250458},
#  {'label': 'neutral', 'score': 0.5883790850639343},
#  {'label': 'neutral', 'score': 0.7249132394790649},
#  {'label': 'neutral', 'score': 0.9201207160949707},
#  {'label': 'negative', 'score': 0.9009292125701904},
#  {'label': 'neutral', 'score': 0.884697675704956},
#  {'label': 'neutral', 'score': 0.8348538279533386},
#  {'label': 'neutral', 'score': 0.8744788765907288},
#  {'label': 'neutral', 'score': 0.618224024772644},
#  {'label': 'neutral', 'score': 0.6239671111106873},
#  {'label': 'positive', 'score': 0.7492661476135254},
#  {'label': 'neutral', 'score': 0.6946190595626831},
#  {'label': 'neutral', 'score': 0.6055611371994019},
#  {'label': 'negative', 'score': 0.6213148832321167},
#  {'label': 'negative', 'score': 0.7531186938285828},
#  {'label': 'neutral', 'score': 0.4553319215774536},
#  {'label': 'neutral', 'score': 0.48459020256996155},
#  {'label': 'neutral', 'score': 0.5144046545028687},
#  {'label': 'neutral', 'score': 0.47214293479919434},
#  {'label': 'neutral', 'score': 0.5850092768669128},
#  {'label': 'neutral', 'score': 0.689415693283081},
#  {'label': 'neutral', 'score': 0.8209351301193237},
#  {'label': 'neutral', 'score': 0.8721545934677124},
#  {'label': 'neutral', 'score': 0.563603937625885},
#  {'label': 'positive', 'score': 0.48418256640434265},
#  {'label': 'neutral', 'score': 0.5468103885650635},
#  {'label': 'negative', 'score': 0.5690169930458069},
#  {'label': 'neutral', 'score': 0.5647855401039124},
#  {'label': 'positive', 'score': 0.9577255845069885},
#  {'label': 'neutral', 'score': 0.6172311902046204},
#  {'label': 'neutral', 'score': 0.880469024181366},
#  {'label': 'neutral', 'score': 0.8065406084060669},
#  {'label': 'negative', 'score': 0.8823935985565186},
#  {'label': 'negative', 'score': 0.6971035599708557},
#  {'label': 'neutral', 'score': 0.622180163860321},
#  {'label': 'negative', 'score': 0.5134093761444092},
#  {'label': 'neutral', 'score': 0.8985583186149597},
#  {'label': 'neutral', 'score': 0.7675466537475586},
#  {'label': 'neutral', 'score': 0.9537549614906311},
#  {'label': 'positive', 'score': 0.8605231046676636},
#  {'label': 'neutral', 'score': 0.6419378519058228},
#  {'label': 'neutral', 'score': 0.7325589060783386},
#  {'label': 'neutral', 'score': 0.9426930546760559},
#  {'label': 'negative', 'score': 0.7926262617111206},
#  {'label': 'negative', 'score': 0.6829239130020142},
#  {'label': 'neutral', 'score': 0.7317768931388855},
#  {'label': 'neutral', 'score': 0.6007573008537292},
#  {'label': 'neutral', 'score': 0.9463486075401306},
#  {'label': 'neutral', 'score': 0.571003258228302},
#  {'label': 'neutral', 'score': 0.8894188404083252},
#  {'label': 'neutral', 'score': 0.7707061767578125},
#  {'label': 'neutral', 'score': 0.8816882967948914},
#  {'label': 'negative', 'score': 0.6672967672348022},
#  {'label': 'neutral', 'score': 0.8560835123062134},
#  {'label': 'neutral', 'score': 0.5200279951095581},
#  {'label': 'neutral', 'score': 0.6097016930580139},
#  {'label': 'neutral', 'score': 0.7116883993148804},
#  {'label': 'neutral', 'score': 0.5226364135742188},
#  {'label': 'neutral', 'score': 0.7517396211624146},
#  {'label': 'neutral', 'score': 0.7639029026031494},
#  {'label': 'positive', 'score': 0.7120370864868164},
#  {'label': 'neutral', 'score': 0.5441460013389587},
#  {'label': 'neutral', 'score': 0.8756749629974365},
#  {'label': 'negative', 'score': 0.6374629139900208},
#  {'label': 'neutral', 'score': 0.868286669254303},
#  {'label': 'negative', 'score': 0.6519160866737366},
#  {'label': 'negative', 'score': 0.8246443271636963},
#  {'label': 'neutral', 'score': 0.6472033262252808},
#  {'label': 'neutral', 'score': 0.7190762162208557},
#  {'label': 'neutral', 'score': 0.7403841018676758},
#  {'label': 'negative', 'score': 0.9079656004905701},
#  {'label': 'negative', 'score': 0.5133801698684692},
#  {'label': 'negative', 'score': 0.907415509223938},
#  {'label': 'neutral', 'score': 0.6187192797660828},
#  {'label': 'neutral', 'score': 0.8378171920776367},
#  {'label': 'positive', 'score': 0.9931803941726685},
#  {'label': 'neutral', 'score': 0.746753454208374},
#  {'label': 'neutral', 'score': 0.7056057453155518},
#  {'label': 'positive', 'score': 0.5983008146286011},
#  {'label': 'negative', 'score': 0.8712860345840454},
#  {'label': 'positive', 'score': 0.88095623254776},
#  {'label': 'negative', 'score': 0.6707001328468323},
#  {'label': 'negative', 'score': 0.9326367974281311},
#  {'label': 'neutral', 'score': 0.5432891845703125},
#  {'label': 'neutral', 'score': 0.5432891845703125},
#  {'label': 'neutral', 'score': 0.5669859051704407},
#  {'label': 'neutral', 'score': 0.9293531179428101},
#  {'label': 'neutral', 'score': 0.6990224123001099},
#  {'label': 'neutral', 'score': 0.6492118835449219},
#  {'label': 'neutral', 'score': 0.7260582447052002},
#  {'label': 'neutral', 'score': 0.6733865141868591},
#  {'label': 'negative', 'score': 0.5646121501922607},
#  {'label': 'neutral', 'score': 0.6323434710502625},
#  {'label': 'neutral', 'score': 0.8990711569786072},
#  {'label': 'negative', 'score': 0.9436734914779663},
#  {'label': 'negative', 'score': 0.5623241066932678},
#  {'label': 'negative', 'score': 0.8785994052886963},
#  {'label': 'neutral', 'score': 0.7289141416549683},
#  {'label': 'negative', 'score': 0.9668410420417786},
#  {'label': 'negative', 'score': 0.7473755478858948},
#  {'label': 'neutral', 'score': 0.7540072202682495},
#  {'label': 'neutral', 'score': 0.5457491278648376},
#  {'label': 'negative', 'score': 0.9668410420417786},
#  {'label': 'neutral', 'score': 0.6158484816551208},
#  {'label': 'neutral', 'score': 0.5919684767723083},
#  {'label': 'negative', 'score': 0.8536843657493591},
#  {'label': 'neutral', 'score': 0.6246707439422607},
#  {'label': 'neutral', 'score': 0.786227822303772},
#  {'label': 'negative', 'score': 0.968691885471344},
#  {'label': 'neutral', 'score': 0.4645131826400757},
#  {'label': 'negative', 'score': 0.8740246295928955},
#  {'label': 'positive', 'score': 0.7877165675163269},
#  {'label': 'negative', 'score': 0.6538629531860352},
#  {'label': 'negative', 'score': 0.9662985801696777},
#  {'label': 'neutral', 'score': 0.8715287446975708},
#  {'label': 'negative', 'score': 0.9668410420417786},
#  {'label': 'neutral', 'score': 0.7745231986045837},
#  {'label': 'negative', 'score': 0.9668410420417786},
#  {'label': 'neutral', 'score': 0.7126192450523376},
#  {'label': 'neutral', 'score': 0.5386624336242676},
#  {'label': 'negative', 'score': 0.7342542409896851},
#  {'label': 'neutral', 'score': 0.8742120265960693},
#  {'label': 'neutral', 'score': 0.5351567268371582},
#  {'label': 'negative', 'score': 0.6178321838378906},
#  {'label': 'neutral', 'score': 0.6445601582527161},
#  {'label': 'neutral', 'score': 0.7840790152549744},
#  {'label': 'neutral', 'score': 0.5712476372718811},
#  {'label': 'neutral', 'score': 0.6072593331336975},
#  {'label': 'neutral', 'score': 0.6847207546234131},
#  {'label': 'neutral', 'score': 0.654655933380127},
#  {'label': 'neutral', 'score': 0.865597665309906},
#  {'label': 'neutral', 'score': 0.9176368117332458},
#  {'label': 'neutral', 'score': 0.44986072182655334},
#  {'label': 'negative', 'score': 0.9373942613601685},
#  {'label': 'neutral', 'score': 0.7891280651092529},
#  {'label': 'neutral', 'score': 0.6662473082542419},
#  {'label': 'negative', 'score': 0.8150721788406372},
#  {'label': 'negative', 'score': 0.8816803097724915},
#  {'label': 'neutral', 'score': 0.8617351055145264},
#  {'label': 'neutral', 'score': 0.8147484064102173},
#  {'label': 'neutral', 'score': 0.5635731816291809},
#  {'label': 'neutral', 'score': 0.7168694138526917},
#  {'label': 'neutral', 'score': 0.8605145215988159},
#  {'label': 'neutral', 'score': 0.763444721698761},
#  {'label': 'negative', 'score': 0.7089754939079285},
#  {'label': 'neutral', 'score': 0.8898265957832336},
#  {'label': 'neutral', 'score': 0.6327483654022217},
#  {'label': 'neutral', 'score': 0.5224609971046448},
#  {'label': 'negative', 'score': 0.7859100103378296},
#  {'label': 'neutral', 'score': 0.8482702374458313},
#  {'label': 'neutral', 'score': 0.7054174542427063},
#  {'label': 'neutral', 'score': 0.7794424295425415},
#  {'label': 'neutral', 'score': 0.7332994937896729},
#  {'label': 'neutral', 'score': 0.8524379134178162},
#  {'label': 'neutral', 'score': 0.7825717926025391},
#  {'label': 'neutral', 'score': 0.5136648416519165},
#  {'label': 'neutral', 'score': 0.8257615566253662},
#  {'label': 'negative', 'score': 0.5163459777832031},
#  {'label': 'positive', 'score': 0.528228759765625},
#  {'label': 'negative', 'score': 0.766866147518158},
#  {'label': 'negative', 'score': 0.5236981511116028},
#  {'label': 'neutral', 'score': 0.6608432531356812},
#  {'label': 'negative', 'score': 0.9495463967323303},
#  {'label': 'negative', 'score': 0.8028925061225891},
#  {'label': 'neutral', 'score': 0.6451610922813416},
#  {'label': 'negative', 'score': 0.5658868551254272},
#  {'label': 'neutral', 'score': 0.852336585521698},
#  {'label': 'neutral', 'score': 0.6766550540924072},
#  {'label': 'neutral', 'score': 0.8242554068565369},
#  {'label': 'neutral', 'score': 0.7766464352607727},
#  {'label': 'negative', 'score': 0.6297693252563477},
#  {'label': 'positive', 'score': 0.8665362596511841},
#  {'label': 'neutral', 'score': 0.5183535218238831},
#  {'label': 'neutral', 'score': 0.8663150072097778},
#  {'label': 'neutral', 'score': 0.7644637823104858},
#  {'label': 'neutral', 'score': 0.6180589199066162},
#  {'label': 'neutral', 'score': 0.7417165637016296},
#  {'label': 'neutral', 'score': 0.8557475805282593},
#  {'label': 'neutral', 'score': 0.6003535389900208},
#  {'label': 'negative', 'score': 0.9186415076255798},
#  {'label': 'negative', 'score': 0.5439968705177307},
#  {'label': 'neutral', 'score': 0.7198972105979919},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'negative', 'score': 0.5470919013023376},
#  {'label': 'neutral', 'score': 0.8451117277145386},
#  {'label': 'neutral', 'score': 0.6366764307022095},
#  {'label': 'neutral', 'score': 0.7462950348854065},
#  {'label': 'neutral', 'score': 0.8813166618347168},
#  {'label': 'negative', 'score': 0.8566004633903503},
#  {'label': 'negative', 'score': 0.44745227694511414},
#  {'label': 'negative', 'score': 0.6152992248535156},
#  {'label': 'neutral', 'score': 0.7018016576766968},
#  {'label': 'neutral', 'score': 0.577526867389679},
#  {'label': 'neutral', 'score': 0.736798107624054},
#  {'label': 'neutral', 'score': 0.7884308695793152},
#  {'label': 'neutral', 'score': 0.5301254987716675},
#  {'label': 'neutral', 'score': 0.9405463933944702},
#  {'label': 'neutral', 'score': 0.7685374021530151},
#  {'label': 'negative', 'score': 0.502717137336731},
#  {'label': 'negative', 'score': 0.7159908413887024},
#  {'label': 'neutral', 'score': 0.5669174194335938},
#  {'label': 'negative', 'score': 0.704962968826294},
#  {'label': 'positive', 'score': 0.9844986796379089},
#  {'label': 'neutral', 'score': 0.8235909342765808},
#  {'label': 'negative', 'score': 0.7990778088569641},
#  {'label': 'neutral', 'score': 0.8132368326187134},
#  {'label': 'neutral', 'score': 0.5612620115280151},
#  {'label': 'neutral', 'score': 0.8326743841171265},
#  {'label': 'positive', 'score': 0.9877245426177979},
#  {'label': 'neutral', 'score': 0.6333642601966858},
#  {'label': 'positive', 'score': 0.5777089595794678},
#  {'label': 'negative', 'score': 0.4816061854362488},
#  {'label': 'neutral', 'score': 0.6929115653038025},
#  {'label': 'negative', 'score': 0.6738605499267578},
#  {'label': 'neutral', 'score': 0.6810358762741089},
#  {'label': 'negative', 'score': 0.5471956133842468},
#  {'label': 'positive', 'score': 0.9552250504493713},
#  {'label': 'neutral', 'score': 0.7694747447967529},
#  {'label': 'negative', 'score': 0.8160791397094727},
#  {'label': 'negative', 'score': 0.918706476688385},
#  {'label': 'negative', 'score': 0.7333734035491943},
#  {'label': 'neutral', 'score': 0.8978014588356018},
#  {'label': 'neutral', 'score': 0.6683157682418823},
#  {'label': 'negative', 'score': 0.7969499230384827},
#  {'label': 'neutral', 'score': 0.9211995601654053},
#  {'label': 'neutral', 'score': 0.8739855885505676},
#  {'label': 'neutral', 'score': 0.7042325139045715},
#  {'label': 'neutral', 'score': 0.6050688028335571},
#  {'label': 'neutral', 'score': 0.5403504371643066},
#  {'label': 'neutral', 'score': 0.7075997591018677},
#  {'label': 'neutral', 'score': 0.7538836598396301},
#  {'label': 'negative', 'score': 0.8300591111183167},
#  {'label': 'neutral', 'score': 0.7442377805709839},
#  {'label': 'neutral', 'score': 0.6315894722938538},
#  {'label': 'negative', 'score': 0.7007671594619751},
#  {'label': 'neutral', 'score': 0.6501020789146423},
#  {'label': 'negative', 'score': 0.9448405504226685},
#  {'label': 'negative', 'score': 0.5509441494941711},
#  {'label': 'neutral', 'score': 0.7940097451210022},
#  {'label': 'positive', 'score': 0.9814369082450867},
#  {'label': 'neutral', 'score': 0.740025520324707},
#  {'label': 'neutral', 'score': 0.8258115649223328},
#  {'label': 'negative', 'score': 0.5245890617370605},
#  {'label': 'neutral', 'score': 0.6539075374603271},
#  {'label': 'neutral', 'score': 0.9456062316894531},
#  {'label': 'negative', 'score': 0.8946226239204407},
#  {'label': 'neutral', 'score': 0.636643648147583},
#  {'label': 'neutral', 'score': 0.8894538879394531},
#  {'label': 'negative', 'score': 0.7968611717224121},
#  {'label': 'negative', 'score': 0.9047450423240662},
#  {'label': 'neutral', 'score': 0.833180844783783},
#  {'label': 'neutral', 'score': 0.7743158340454102},
#  {'label': 'positive', 'score': 0.6385377049446106},
#  {'label': 'neutral', 'score': 0.7602574229240417},
#  {'label': 'neutral', 'score': 0.8041812777519226},
#  {'label': 'neutral', 'score': 0.7079252004623413},
#  {'label': 'neutral', 'score': 0.8346678614616394},
#  {'label': 'neutral', 'score': 0.5647609829902649},
#  {'label': 'neutral', 'score': 0.4976724684238434},
#  {'label': 'neutral', 'score': 0.8015570640563965},
#  {'label': 'positive', 'score': 0.4824041724205017},
#  {'label': 'negative', 'score': 0.673668384552002},
#  {'label': 'negative', 'score': 0.7710933685302734},
#  {'label': 'neutral', 'score': 0.8869845867156982},
#  {'label': 'neutral', 'score': 0.9231616258621216},
#  {'label': 'negative', 'score': 0.7769960761070251},
#  {'label': 'neutral', 'score': 0.9096193909645081},
#  {'label': 'neutral', 'score': 0.8109533190727234},
#  {'label': 'negative', 'score': 0.7808728814125061},
#  {'label': 'neutral', 'score': 0.669161856174469},
#  {'label': 'negative', 'score': 0.7195744514465332},
#  {'label': 'neutral', 'score': 0.6614995002746582},
#  {'label': 'positive', 'score': 0.3509993255138397},
#  {'label': 'neutral', 'score': 0.9191686511039734},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'neutral', 'score': 0.8913035988807678},
#  {'label': 'neutral', 'score': 0.6026431918144226},
#  {'label': 'neutral', 'score': 0.6446220874786377},
#  {'label': 'neutral', 'score': 0.5645636916160583},
#  {'label': 'neutral', 'score': 0.6816808581352234},
#  {'label': 'positive', 'score': 0.7848169803619385},
#  {'label': 'neutral', 'score': 0.7943110466003418},
#  {'label': 'neutral', 'score': 0.8045429587364197},
#  {'label': 'negative', 'score': 0.8774203658103943},
#  {'label': 'positive', 'score': 0.9519733190536499},
#  {'label': 'positive', 'score': 0.5634100437164307},
#  {'label': 'negative', 'score': 0.5642542839050293},
#  {'label': 'positive', 'score': 0.7054046392440796},
#  {'label': 'negative', 'score': 0.7245262265205383},
#  {'label': 'neutral', 'score': 0.5137127041816711},
#  {'label': 'negative', 'score': 0.5547127723693848},
#  {'label': 'neutral', 'score': 0.8958449363708496},
#  {'label': 'neutral', 'score': 0.8083782196044922},
#  {'label': 'neutral', 'score': 0.8792557716369629},
#  {'label': 'neutral', 'score': 0.772369921207428},
#  {'label': 'neutral', 'score': 0.7419650554656982},
#  {'label': 'negative', 'score': 0.7737534642219543},
#  {'label': 'neutral', 'score': 0.7844858765602112},
#  {'label': 'negative', 'score': 0.6837380528450012},
#  {'label': 'neutral', 'score': 0.7122339606285095},
#  {'label': 'neutral', 'score': 0.7968387007713318},
#  {'label': 'positive', 'score': 0.5188270807266235},
#  {'label': 'neutral', 'score': 0.8452731966972351},
#  {'label': 'neutral', 'score': 0.7624658346176147},
#  {'label': 'negative', 'score': 0.5143717527389526},
#  {'label': 'neutral', 'score': 0.6523603796958923},
#  {'label': 'positive', 'score': 0.5298319458961487},
#  {'label': 'neutral', 'score': 0.8864396214485168},
#  {'label': 'positive', 'score': 0.8463798761367798},
#  {'label': 'neutral', 'score': 0.716817319393158},
#  {'label': 'neutral', 'score': 0.8717976808547974},
#  {'label': 'neutral', 'score': 0.7923186421394348},
#  {'label': 'positive', 'score': 0.6127626299858093},
#  {'label': 'neutral', 'score': 0.5872259140014648},
#  {'label': 'neutral', 'score': 0.9323132634162903},
#  {'label': 'negative', 'score': 0.6022458672523499},
#  {'label': 'neutral', 'score': 0.7299482822418213},
#  {'label': 'negative', 'score': 0.5188466310501099},
#  {'label': 'neutral', 'score': 0.7555210590362549},
#  {'label': 'positive', 'score': 0.47628214955329895},
#  {'label': 'neutral', 'score': 0.7502440810203552},
#  {'label': 'neutral', 'score': 0.6326269507408142},
#  {'label': 'neutral', 'score': 0.7997913956642151},
#  {'label': 'neutral', 'score': 0.7553359866142273},
#  {'label': 'neutral', 'score': 0.8848662376403809},
#  {'label': 'neutral', 'score': 0.921164870262146},
#  {'label': 'neutral', 'score': 0.8772982358932495},
#  {'label': 'neutral', 'score': 0.6175214648246765},
#  {'label': 'positive', 'score': 0.49195799231529236},
#  {'label': 'neutral', 'score': 0.6706212162971497},
#  {'label': 'neutral', 'score': 0.8615333437919617},
#  {'label': 'neutral', 'score': 0.6429177522659302},
#  {'label': 'neutral', 'score': 0.6444692015647888},
#  {'label': 'neutral', 'score': 0.5880547165870667},
#  {'label': 'negative', 'score': 0.5270317792892456},
#  {'label': 'neutral', 'score': 0.8268667459487915},
#  {'label': 'neutral', 'score': 0.7694265842437744},
#  {'label': 'positive', 'score': 0.5426614880561829},
#  {'label': 'neutral', 'score': 0.8125587105751038},
#  {'label': 'neutral', 'score': 0.8171799778938293},
#  {'label': 'neutral', 'score': 0.8461543917655945},
#  {'label': 'neutral', 'score': 0.8659003376960754},
#  {'label': 'neutral', 'score': 0.5131446123123169},
#  {'label': 'neutral', 'score': 0.8734813332557678},
#  {'label': 'neutral', 'score': 0.9086900949478149},
#  {'label': 'neutral', 'score': 0.9068577885627747},
#  {'label': 'neutral', 'score': 0.8041777610778809},
#  {'label': 'neutral', 'score': 0.6222701072692871},
#  {'label': 'neutral', 'score': 0.6513988971710205},
#  {'label': 'neutral', 'score': 0.8262091279029846},
#  {'label': 'positive', 'score': 0.5116215944290161},
#  {'label': 'negative', 'score': 0.5669502019882202},
#  {'label': 'neutral', 'score': 0.8980723023414612},
#  {'label': 'negative', 'score': 0.5766350030899048},
#  {'label': 'negative', 'score': 0.6990558505058289},
#  {'label': 'negative', 'score': 0.7156489491462708},
#  {'label': 'neutral', 'score': 0.8683322668075562},
#  {'label': 'neutral', 'score': 0.9431266784667969},
#  {'label': 'neutral', 'score': 0.6387662887573242},
#  {'label': 'neutral', 'score': 0.6142488718032837},
#  {'label': 'neutral', 'score': 0.6911699175834656},
#  {'label': 'neutral', 'score': 0.6945165395736694},
#  {'label': 'negative', 'score': 0.728578507900238},
#  {'label': 'neutral', 'score': 0.7391387820243835},
#  {'label': 'neutral', 'score': 0.6777790784835815},
#  {'label': 'neutral', 'score': 0.6437420845031738},
#  {'label': 'neutral', 'score': 0.7856971025466919},
#  {'label': 'neutral', 'score': 0.7468908429145813},
#  {'label': 'neutral', 'score': 0.5366246700286865},
#  {'label': 'neutral', 'score': 0.8774058818817139},
#  {'label': 'negative', 'score': 0.5741729140281677},
#  {'label': 'neutral', 'score': 0.49829524755477905},
#  {'label': 'neutral', 'score': 0.9101116061210632},
#  {'label': 'negative', 'score': 0.7417395114898682},
#  {'label': 'neutral', 'score': 0.8918187618255615},
#  {'label': 'neutral', 'score': 0.7452458739280701},
#  {'label': 'neutral', 'score': 0.8018430471420288},
#  {'label': 'neutral', 'score': 0.8313198089599609},
#  {'label': 'negative', 'score': 0.5277059674263},
#  {'label': 'negative', 'score': 0.7047726511955261},
#  {'label': 'neutral', 'score': 0.77435702085495},
#  {'label': 'neutral', 'score': 0.5448529720306396},
#  {'label': 'neutral', 'score': 0.6582293510437012},
#  {'label': 'neutral', 'score': 0.6883357763290405},
#  {'label': 'negative', 'score': 0.6037786602973938},
#  {'label': 'neutral', 'score': 0.7224640846252441},
#  {'label': 'neutral', 'score': 0.718813419342041},
#  {'label': 'negative', 'score': 0.9259878396987915},
#  {'label': 'neutral', 'score': 0.7892547845840454},
#  {'label': 'negative', 'score': 0.5616528987884521},
#  {'label': 'neutral', 'score': 0.8822740912437439},
#  {'label': 'negative', 'score': 0.8055622577667236},
#  {'label': 'positive', 'score': 0.525698721408844},
#  {'label': 'negative', 'score': 0.49608927965164185},
#  {'label': 'neutral', 'score': 0.6989567875862122},
#  {'label': 'negative', 'score': 0.7638247013092041},
#  {'label': 'neutral', 'score': 0.8788484930992126},
#  {'label': 'neutral', 'score': 0.5865774154663086},
#  {'label': 'neutral', 'score': 0.8852940201759338},
#  {'label': 'neutral', 'score': 0.7630777955055237},
#  {'label': 'neutral', 'score': 0.9112740755081177},
#  {'label': 'neutral', 'score': 0.8369815945625305},
#  {'label': 'neutral', 'score': 0.801289439201355},
#  {'label': 'negative', 'score': 0.9210830330848694},
#  {'label': 'neutral', 'score': 0.9289171099662781},
#  {'label': 'neutral', 'score': 0.9187694787979126},
#  {'label': 'neutral', 'score': 0.7886868119239807},
#  {'label': 'neutral', 'score': 0.8554080724716187},
#  {'label': 'neutral', 'score': 0.8780152797698975},
#  {'label': 'negative', 'score': 0.5592747926712036},
#  {'label': 'neutral', 'score': 0.8019915819168091},
#  {'label': 'neutral', 'score': 0.8125476837158203},
#  {'label': 'neutral', 'score': 0.8869116306304932},
#  {'label': 'neutral', 'score': 0.9235379695892334},
#  {'label': 'neutral', 'score': 0.8938782215118408},
#  {'label': 'neutral', 'score': 0.8111411333084106},
#  {'label': 'neutral', 'score': 0.7666511535644531},
#  {'label': 'neutral', 'score': 0.8514487147331238},
#  {'label': 'negative', 'score': 0.8583943247795105},
#  {'label': 'neutral', 'score': 0.6255816221237183},
#  {'label': 'neutral', 'score': 0.7379505634307861},
#  {'label': 'neutral', 'score': 0.8787020444869995},
#  {'label': 'neutral', 'score': 0.9105038642883301},
#  {'label': 'negative', 'score': 0.7096710205078125},
#  {'label': 'neutral', 'score': 0.8686098456382751},
#  {'label': 'neutral', 'score': 0.9504594802856445},
#  {'label': 'neutral', 'score': 0.8682490587234497},
#  {'label': 'neutral', 'score': 0.7546195387840271},
#  {'label': 'negative', 'score': 0.9377608299255371},
#  {'label': 'neutral', 'score': 0.9156105518341064},
#  {'label': 'positive', 'score': 0.5108511447906494},
#  {'label': 'positive', 'score': 0.8424402475357056},
#  {'label': 'neutral', 'score': 0.7637770175933838},
#  {'label': 'neutral', 'score': 0.9018656611442566},
#  {'label': 'neutral', 'score': 0.796919584274292},
#  {'label': 'negative', 'score': 0.43333157896995544},
#  {'label': 'neutral', 'score': 0.8422319889068604},
#  {'label': 'negative', 'score': 0.5003203749656677},
#  {'label': 'neutral', 'score': 0.8531851172447205},
#  {'label': 'neutral', 'score': 0.8572874069213867},
#  {'label': 'negative', 'score': 0.8671658635139465},
#  {'label': 'neutral', 'score': 0.788875162601471},
#  {'label': 'neutral', 'score': 0.5915669202804565},
#  {'label': 'neutral', 'score': 0.9267104268074036},
#  {'label': 'neutral', 'score': 0.8469847440719604},
#  {'label': 'neutral', 'score': 0.9393212199211121},
#  {'label': 'neutral', 'score': 0.8787755966186523},
#  {'label': 'neutral', 'score': 0.8690527081489563},
#  {'label': 'neutral', 'score': 0.923008143901825},
#  {'label': 'negative', 'score': 0.6296323537826538},
#  {'label': 'negative', 'score': 0.7675449848175049},
#  {'label': 'neutral', 'score': 0.6661573648452759},
#  {'label': 'neutral', 'score': 0.84392911195755},
#  {'label': 'neutral', 'score': 0.8126919269561768},
#  {'label': 'neutral', 'score': 0.6662613749504089},
#  {'label': 'positive', 'score': 0.7087520956993103},
#  {'label': 'neutral', 'score': 0.8626704216003418},
#  {'label': 'neutral', 'score': 0.7651432156562805},
#  {'label': 'neutral', 'score': 0.6370002031326294},
#  {'label': 'neutral', 'score': 0.8154811859130859},
#  {'label': 'neutral', 'score': 0.6583719253540039},
#  {'label': 'negative', 'score': 0.6643434762954712},
#  {'label': 'neutral', 'score': 0.8161250352859497},
#  {'label': 'neutral', 'score': 0.8984755277633667},
#  {'label': 'neutral', 'score': 0.8394019603729248},
#  {'label': 'neutral', 'score': 0.9032559990882874},
#  {'label': 'positive', 'score': 0.8333145976066589},
#  {'label': 'neutral', 'score': 0.70272296667099},
#  {'label': 'neutral', 'score': 0.7825968861579895},
#  {'label': 'neutral', 'score': 0.8117332458496094},
#  {'label': 'negative', 'score': 0.5221536755561829},
#  {'label': 'neutral', 'score': 0.8493420481681824},
#  {'label': 'neutral', 'score': 0.8300260901451111},
#  {'label': 'neutral', 'score': 0.9105168581008911},
#  {'label': 'neutral', 'score': 0.8691946268081665},
#  {'label': 'neutral', 'score': 0.8446254730224609},
#  {'label': 'neutral', 'score': 0.917667806148529},
#  {'label': 'neutral', 'score': 0.5455086827278137},
#  {'label': 'neutral', 'score': 0.7934480905532837},
#  {'label': 'neutral', 'score': 0.7214601635932922},
#  {'label': 'negative', 'score': 0.519776463508606},
#  {'label': 'neutral', 'score': 0.57204669713974},
#  {'label': 'neutral', 'score': 0.6990447044372559},
#  {'label': 'neutral', 'score': 0.8908566236495972},
#  {'label': 'negative', 'score': 0.9230876564979553},
#  {'label': 'negative', 'score': 0.719471275806427},
#  {'label': 'neutral', 'score': 0.7759890556335449},
#  {'label': 'neutral', 'score': 0.699862003326416},
#  {'label': 'neutral', 'score': 0.7844358086585999},
#  {'label': 'neutral', 'score': 0.8453559279441833},
#  {'label': 'neutral', 'score': 0.7635183334350586},
#  {'label': 'neutral', 'score': 0.9608715176582336},
#  {'label': 'neutral', 'score': 0.6187458038330078},
#  {'label': 'neutral', 'score': 0.7537816166877747},
#  {'label': 'neutral', 'score': 0.852272093296051},
#  {'label': 'neutral', 'score': 0.6346542835235596},
#  {'label': 'neutral', 'score': 0.873845100402832},
#  {'label': 'neutral', 'score': 0.9236395359039307},
#  {'label': 'neutral', 'score': 0.5793663859367371},
#  {'label': 'neutral', 'score': 0.8257161974906921},
#  {'label': 'neutral', 'score': 0.6478871703147888},
#  {'label': 'neutral', 'score': 0.886728048324585},
#  {'label': 'neutral', 'score': 0.9250914454460144},
#  {'label': 'neutral', 'score': 0.5703533291816711},
#  {'label': 'neutral', 'score': 0.9420222043991089},
#  {'label': 'neutral', 'score': 0.8680198192596436},
#  {'label': 'neutral', 'score': 0.914111852645874},
#  {'label': 'neutral', 'score': 0.7670429944992065},
#  {'label': 'neutral', 'score': 0.6226759552955627},
#  {'label': 'neutral', 'score': 0.7693079113960266},
#  {'label': 'positive', 'score': 0.8590928912162781},
#  {'label': 'neutral', 'score': 0.7745267748832703},
#  {'label': 'neutral', 'score': 0.6805087327957153},
#  {'label': 'positive', 'score': 0.533932626247406},
#  {'label': 'neutral', 'score': 0.6787901520729065},
#  {'label': 'neutral', 'score': 0.8006946444511414},
#  {'label': 'negative', 'score': 0.5614833831787109},
#  {'label': 'neutral', 'score': 0.9127377867698669},
#  {'label': 'neutral', 'score': 0.8202435970306396},
#  {'label': 'positive', 'score': 0.7566532492637634},
#  {'label': 'neutral', 'score': 0.7854422330856323},
#  {'label': 'neutral', 'score': 0.8241692185401917},
#  {'label': 'neutral', 'score': 0.46759721636772156},
#  {'label': 'neutral', 'score': 0.767241895198822},
#  {'label': 'neutral', 'score': 0.7996206879615784},
#  {'label': 'neutral', 'score': 0.6133639216423035},
#  {'label': 'neutral', 'score': 0.7025548815727234},
#  {'label': 'neutral', 'score': 0.8346748352050781},
#  {'label': 'neutral', 'score': 0.7090135812759399},
#  {'label': 'neutral', 'score': 0.6991176009178162},
#  {'label': 'neutral', 'score': 0.8395262360572815},
#  {'label': 'neutral', 'score': 0.640920877456665},
#  {'label': 'negative', 'score': 0.7581664323806763},
#  {'label': 'neutral', 'score': 0.8377375602722168},
#  {'label': 'negative', 'score': 0.6361400485038757},
#  {'label': 'positive', 'score': 0.914139449596405},
#  {'label': 'neutral', 'score': 0.8766201734542847},
#  {'label': 'neutral', 'score': 0.883721113204956},
#  {'label': 'neutral', 'score': 0.8431569933891296},
#  {'label': 'neutral', 'score': 0.9067993760108948},
#  {'label': 'neutral', 'score': 0.8398468494415283},
#  {'label': 'neutral', 'score': 0.8432563543319702},
#  {'label': 'neutral', 'score': 0.919378399848938},
#  {'label': 'neutral', 'score': 0.549894392490387},
#  {'label': 'neutral', 'score': 0.9009364247322083},
#  {'label': 'neutral', 'score': 0.8337817192077637},
#  {'label': 'negative', 'score': 0.8173521757125854},
#  {'label': 'negative', 'score': 0.8353223204612732},
#  {'label': 'neutral', 'score': 0.8598179817199707},
#  {'label': 'neutral', 'score': 0.8207023739814758},
#  {'label': 'neutral', 'score': 0.9521719217300415},
#  {'label': 'neutral', 'score': 0.8978968858718872},
#  {'label': 'neutral', 'score': 0.5143092274665833},
#  {'label': 'neutral', 'score': 0.760499119758606},
#  {'label': 'positive', 'score': 0.90101158618927},
#  {'label': 'neutral', 'score': 0.9067926406860352},
#  {'label': 'neutral', 'score': 0.7350769639015198},
#  {'label': 'neutral', 'score': 0.8408281803131104},
#  {'label': 'neutral', 'score': 0.7206473350524902},
#  {'label': 'neutral', 'score': 0.9394071698188782},
#  {'label': 'positive', 'score': 0.9466812610626221},
#  {'label': 'neutral', 'score': 0.8398134708404541},
#  {'label': 'neutral', 'score': 0.6414229869842529},
#  {'label': 'neutral', 'score': 0.5345166921615601},
#  {'label': 'neutral', 'score': 0.8025171160697937},
#  {'label': 'neutral', 'score': 0.5102877616882324},
#  {'label': 'neutral', 'score': 0.6785213947296143},
#  {'label': 'neutral', 'score': 0.8643564581871033},
#  {'label': 'neutral', 'score': 0.6025151014328003},
#  {'label': 'neutral', 'score': 0.8337372541427612},
#  {'label': 'positive', 'score': 0.7823518514633179},
#  {'label': 'positive', 'score': 0.9799612164497375},
#  {'label': 'neutral', 'score': 0.5693101286888123},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'neutral', 'score': 0.9067926406860352},
#  {'label': 'neutral', 'score': 0.926353394985199},
#  {'label': 'positive', 'score': 0.9693037867546082},
#  {'label': 'neutral', 'score': 0.7778498530387878},
#  {'label': 'neutral', 'score': 0.8811126351356506},
#  {'label': 'neutral', 'score': 0.8545899391174316},
#  {'label': 'negative', 'score': 0.6132122874259949},
#  {'label': 'neutral', 'score': 0.7395059466362},
#  {'label': 'neutral', 'score': 0.603531002998352},
#  {'label': 'neutral', 'score': 0.4750783145427704},
#  {'label': 'neutral', 'score': 0.6364272236824036},
#  {'label': 'neutral', 'score': 0.8877508640289307},
#  {'label': 'positive', 'score': 0.9083341956138611},
#  {'label': 'neutral', 'score': 0.905612587928772},
#  {'label': 'neutral', 'score': 0.818722665309906},
#  {'label': 'neutral', 'score': 0.8263087272644043},
#  {'label': 'neutral', 'score': 0.8599379062652588},
#  {'label': 'neutral', 'score': 0.944471538066864},
#  {'label': 'positive', 'score': 0.947262704372406},
#  {'label': 'neutral', 'score': 0.8216356039047241},
#  {'label': 'neutral', 'score': 0.534020721912384},
#  {'label': 'neutral', 'score': 0.5125457644462585},
#  {'label': 'positive', 'score': 0.9735099673271179},
#  {'label': 'neutral', 'score': 0.6837365627288818},
#  {'label': 'neutral', 'score': 0.8825128674507141},
#  {'label': 'neutral', 'score': 0.8354232907295227},
#  {'label': 'neutral', 'score': 0.9175782799720764},
#  {'label': 'neutral', 'score': 0.4100765883922577},
#  {'label': 'neutral', 'score': 0.47808873653411865},
#  {'label': 'negative', 'score': 0.594829261302948},
#  {'label': 'neutral', 'score': 0.5286961197853088},
#  {'label': 'neutral', 'score': 0.8161630034446716},
#  {'label': 'neutral', 'score': 0.6964135766029358},
#  {'label': 'negative', 'score': 0.7616562843322754},
#  {'label': 'neutral', 'score': 0.5994091033935547},
#  {'label': 'neutral', 'score': 0.5533456206321716},
#  {'label': 'neutral', 'score': 0.8224397897720337},
#  {'label': 'neutral', 'score': 0.5502026677131653},
#  {'label': 'neutral', 'score': 0.8524594306945801},
#  {'label': 'neutral', 'score': 0.8009675145149231},
#  {'label': 'neutral', 'score': 0.5139092206954956},
#  {'label': 'neutral', 'score': 0.8027546405792236},
#  {'label': 'neutral', 'score': 0.7323147654533386},
#  {'label': 'neutral', 'score': 0.913539469242096},
#  {'label': 'negative', 'score': 0.952573835849762},
#  {'label': 'negative', 'score': 0.8300313353538513},
#  {'label': 'neutral', 'score': 0.8926525712013245},
#  {'label': 'neutral', 'score': 0.9472047090530396},
#  {'label': 'neutral', 'score': 0.8858708739280701},
#  {'label': 'neutral', 'score': 0.8600100874900818},
#  {'label': 'neutral', 'score': 0.9038782119750977},
#  {'label': 'neutral', 'score': 0.8432320952415466},
#  {'label': 'negative', 'score': 0.7715120315551758},
#  {'label': 'neutral', 'score': 0.9081516861915588},
#  {'label': 'neutral', 'score': 0.5176849961280823},
#  {'label': 'neutral', 'score': 0.906227171421051},
#  {'label': 'negative', 'score': 0.5501052737236023},
#  {'label': 'neutral', 'score': 0.836248517036438},
#  {'label': 'neutral', 'score': 0.8319003582000732},
#  {'label': 'negative', 'score': 0.8183305263519287},
#  {'label': 'negative', 'score': 0.6234042048454285},
#  {'label': 'negative', 'score': 0.6023622751235962},
#  {'label': 'neutral', 'score': 0.906227171421051},
#  {'label': 'neutral', 'score': 0.7621525526046753},
#  {'label': 'neutral', 'score': 0.5924564003944397},
#  {'label': 'neutral', 'score': 0.8132903575897217},
#  {'label': 'neutral', 'score': 0.745885968208313},
#  {'label': 'neutral', 'score': 0.9434431791305542},
#  {'label': 'negative', 'score': 0.46647292375564575},
#  {'label': 'neutral', 'score': 0.6599888205528259},
#  {'label': 'neutral', 'score': 0.7048982977867126},
#  {'label': 'neutral', 'score': 0.5532347559928894},
#  {'label': 'neutral', 'score': 0.8802617192268372},
#  {'label': 'negative', 'score': 0.5247360467910767},
#  {'label': 'neutral', 'score': 0.6614470481872559},
#  {'label': 'neutral', 'score': 0.718027651309967},
#  {'label': 'neutral', 'score': 0.8722613453865051},
#  {'label': 'neutral', 'score': 0.8400987982749939},
#  {'label': 'neutral', 'score': 0.7644906640052795},
#  {'label': 'neutral', 'score': 0.5443373322486877},
#  {'label': 'negative', 'score': 0.7488631010055542},
#  {'label': 'neutral', 'score': 0.38591158390045166},
#  {'label': 'neutral', 'score': 0.9585832357406616},
#  {'label': 'neutral', 'score': 0.701003909111023},
#  {'label': 'neutral', 'score': 0.9526600241661072},
#  {'label': 'neutral', 'score': 0.9004619121551514},
#  {'label': 'neutral', 'score': 0.9110525250434875},
#  {'label': 'neutral', 'score': 0.6076926589012146},
#  {'label': 'neutral', 'score': 0.6417374610900879},
#  {'label': 'neutral', 'score': 0.8622896671295166},
#  {'label': 'positive', 'score': 0.5695374011993408},
#  {'label': 'neutral', 'score': 0.8995554447174072},
#  {'label': 'neutral', 'score': 0.5432708859443665},
#  {'label': 'negative', 'score': 0.6835995316505432},
#  {'label': 'negative', 'score': 0.511253297328949},
#  {'label': 'neutral', 'score': 0.9250828623771667},
#  {'label': 'negative', 'score': 0.7965434193611145},
#  {'label': 'negative', 'score': 0.5763324499130249},
#  {'label': 'neutral', 'score': 0.7162677049636841},
#  {'label': 'neutral', 'score': 0.8122482299804688},
#  {'label': 'neutral', 'score': 0.7557734251022339},
#  {'label': 'negative', 'score': 0.776288628578186},
#  {'label': 'neutral', 'score': 0.8721626996994019},
#  {'label': 'neutral', 'score': 0.7742401361465454},
#  {'label': 'negative', 'score': 0.6042274236679077},
#  {'label': 'neutral', 'score': 0.6678159236907959},
#  {'label': 'neutral', 'score': 0.9233079552650452},
#  {'label': 'neutral', 'score': 0.5038243532180786},
#  {'label': 'neutral', 'score': 0.915507972240448},
#  {'label': 'negative', 'score': 0.7655820846557617},
#  {'label': 'negative', 'score': 0.8207672834396362},
#  {'label': 'neutral', 'score': 0.674005389213562},
#  {'label': 'neutral', 'score': 0.868367612361908},
#  {'label': 'neutral', 'score': 0.655038595199585},
#  {'label': 'neutral', 'score': 0.6810828447341919},
#  {'label': 'negative', 'score': 0.5405953526496887},
#  {'label': 'negative', 'score': 0.8579413890838623},
#  {'label': 'neutral', 'score': 0.849221408367157},
#  {'label': 'neutral', 'score': 0.8921610713005066},
#  {'label': 'neutral', 'score': 0.8810235261917114},
#  {'label': 'neutral', 'score': 0.9028788805007935},
#  {'label': 'neutral', 'score': 0.5677354335784912},
#  {'label': 'neutral', 'score': 0.8727173209190369},
#  {'label': 'neutral', 'score': 0.7653653621673584},
#  {'label': 'neutral', 'score': 0.5389009714126587},
#  {'label': 'neutral', 'score': 0.81302410364151},
#  {'label': 'negative', 'score': 0.6322149038314819},
#  {'label': 'neutral', 'score': 0.8831726908683777},
#  {'label': 'neutral', 'score': 0.9372796416282654},
#  {'label': 'neutral', 'score': 0.579113781452179},
#  {'label': 'neutral', 'score': 0.7562329173088074},
#  {'label': 'neutral', 'score': 0.8897100687026978},
#  {'label': 'negative', 'score': 0.7235284447669983},
#  {'label': 'neutral', 'score': 0.9143582582473755},
#  {'label': 'neutral', 'score': 0.49972328543663025},
#  {'label': 'neutral', 'score': 0.8526556491851807},
#  {'label': 'neutral', 'score': 0.7496477961540222},
#  {'label': 'neutral', 'score': 0.6402773857116699},
#  {'label': 'neutral', 'score': 0.7415921092033386},
#  {'label': 'neutral', 'score': 0.7089259028434753},
#  {'label': 'neutral', 'score': 0.6692970395088196},
#  {'label': 'neutral', 'score': 0.7578709125518799},
#  {'label': 'neutral', 'score': 0.8206565976142883},
#  {'label': 'negative', 'score': 0.7813753485679626},
#  {'label': 'negative', 'score': 0.8897160887718201},
#  {'label': 'negative', 'score': 0.5568951964378357},
#  {'label': 'negative', 'score': 0.9209468364715576},
#  {'label': 'positive', 'score': 0.8401327729225159},
#  {'label': 'neutral', 'score': 0.854538083076477},
#  {'label': 'neutral', 'score': 0.5288649201393127},
#  {'label': 'negative', 'score': 0.9415946006774902},
#  {'label': 'neutral', 'score': 0.860625684261322},
#  {'label': 'neutral', 'score': 0.8431990742683411},
#  {'label': 'neutral', 'score': 0.7892026901245117},
#  {'label': 'neutral', 'score': 0.6680474281311035},
#  {'label': 'negative', 'score': 0.5775141716003418},
#  {'label': 'neutral', 'score': 0.8415042757987976},
#  {'label': 'neutral', 'score': 0.9040483832359314},
#  {'label': 'negative', 'score': 0.5608876943588257},
#  {'label': 'neutral', 'score': 0.8501966595649719},
#  {'label': 'neutral', 'score': 0.7156327962875366},
#  {'label': 'neutral', 'score': 0.8640832304954529},
#  {'label': 'negative', 'score': 0.5573007464408875},
#  {'label': 'neutral', 'score': 0.8042362332344055},
#  {'label': 'neutral', 'score': 0.8706740140914917},
#  {'label': 'neutral', 'score': 0.5302609205245972},
#  {'label': 'neutral', 'score': 0.9029780030250549},
#  {'label': 'neutral', 'score': 0.8750211596488953},
#  {'label': 'neutral', 'score': 0.832889974117279},
#  {'label': 'negative', 'score': 0.6334033608436584},
#  {'label': 'neutral', 'score': 0.6460529565811157},
#  {'label': 'neutral', 'score': 0.6432565450668335},
#  {'label': 'negative', 'score': 0.7098984122276306},
#  {'label': 'negative', 'score': 0.7478485107421875},
#  {'label': 'neutral', 'score': 0.5158785581588745},
#  {'label': 'neutral', 'score': 0.912213146686554},
#  {'label': 'positive', 'score': 0.7641894221305847},
#  {'label': 'neutral', 'score': 0.614348292350769},
#  {'label': 'neutral', 'score': 0.9377129077911377},
#  {'label': 'neutral', 'score': 0.7735234498977661},
#  {'label': 'negative', 'score': 0.8919345736503601},
#  {'label': 'positive', 'score': 0.6669006943702698},
#  {'label': 'neutral', 'score': 0.6734790205955505},
#  {'label': 'neutral', 'score': 0.5148317813873291},
#  {'label': 'neutral', 'score': 0.5457796454429626},
#  {'label': 'neutral', 'score': 0.9181225895881653},
#  {'label': 'neutral', 'score': 0.7999366521835327},
#  {'label': 'neutral', 'score': 0.8527575731277466},
#  {'label': 'neutral', 'score': 0.8869845867156982},
#  {'label': 'neutral', 'score': 0.6287238597869873},
#  {'label': 'neutral', 'score': 0.7881850004196167},
#  {'label': 'neutral', 'score': 0.798668622970581},
#  {'label': 'neutral', 'score': 0.483763724565506},
#  {'label': 'neutral', 'score': 0.796119749546051},
#  {'label': 'neutral', 'score': 0.8094191551208496},
#  {'label': 'neutral', 'score': 0.5777369141578674},
#  {'label': 'neutral', 'score': 0.8900169134140015},
#  {'label': 'neutral', 'score': 0.78052818775177},
#  {'label': 'neutral', 'score': 0.8947950601577759},
#  {'label': 'negative', 'score': 0.5437015295028687},
#  {'label': 'negative', 'score': 0.5172300934791565},
#  {'label': 'neutral', 'score': 0.6067841053009033},
#  {'label': 'neutral', 'score': 0.8646902441978455},
#  {'label': 'negative', 'score': 0.6386457681655884},
#  {'label': 'neutral', 'score': 0.8399781584739685},
#  {'label': 'neutral', 'score': 0.7590077519416809},
#  {'label': 'neutral', 'score': 0.5887011885643005},
#  {'label': 'negative', 'score': 0.5856991410255432},
#  {'label': 'negative', 'score': 0.6557815670967102},
#  {'label': 'neutral', 'score': 0.7648641467094421},
#  {'label': 'neutral', 'score': 0.8666943311691284},
#  {'label': 'neutral', 'score': 0.5329834818840027},
#  {'label': 'neutral', 'score': 0.7608096599578857},
#  {'label': 'neutral', 'score': 0.7041319012641907},
#  {'label': 'negative', 'score': 0.8361185193061829},
#  {'label': 'neutral', 'score': 0.942713737487793},
#  {'label': 'neutral', 'score': 0.6839949488639832},
#  {'label': 'neutral', 'score': 0.8249685764312744},
#  {'label': 'positive', 'score': 0.8004260063171387},
#  {'label': 'negative', 'score': 0.6570010781288147},
#  {'label': 'neutral', 'score': 0.8910474181175232},
#  {'label': 'neutral', 'score': 0.42797714471817017},
#  {'label': 'neutral', 'score': 0.8523465394973755},
#  {'label': 'neutral', 'score': 0.512643575668335},
#  {'label': 'neutral', 'score': 0.7080376744270325},
#  {'label': 'neutral', 'score': 0.9158467054367065},
#  {'label': 'neutral', 'score': 0.5265434384346008},
#  {'label': 'neutral', 'score': 0.9149949550628662},
#  {'label': 'neutral', 'score': 0.6280776858329773},
#  {'label': 'neutral', 'score': 0.6732983589172363},
#  {'label': 'negative', 'score': 0.8079308867454529},
#  {'label': 'neutral', 'score': 0.7463587522506714},
#  {'label': 'neutral', 'score': 0.8384532928466797},
#  {'label': 'neutral', 'score': 0.8098239898681641},
#  {'label': 'neutral', 'score': 0.7220615744590759},
#  {'label': 'neutral', 'score': 0.7697932720184326},
#  {'label': 'neutral', 'score': 0.8592174649238586},
#  {'label': 'neutral', 'score': 0.8697580695152283},
#  {'label': 'neutral', 'score': 0.7662625312805176},
#  {'label': 'neutral', 'score': 0.7583311796188354},
#  {'label': 'positive', 'score': 0.7362286448478699},
#  {'label': 'negative', 'score': 0.8787267208099365},
#  {'label': 'neutral', 'score': 0.7024768590927124},
#  {'label': 'neutral', 'score': 0.8786648511886597},
#  {'label': 'negative', 'score': 0.9196018576622009},
#  {'label': 'positive', 'score': 0.661626398563385},
#  {'label': 'neutral', 'score': 0.8204491138458252},
#  {'label': 'neutral', 'score': 0.62950599193573},
#  {'label': 'negative', 'score': 0.8921738266944885},
#  {'label': 'neutral', 'score': 0.644411563873291},
#  {'label': 'neutral', 'score': 0.848058819770813},
#  {'label': 'neutral', 'score': 0.7103775143623352},
#  {'label': 'negative', 'score': 0.8264181613922119},
#  {'label': 'neutral', 'score': 0.7332885265350342},
#  {'label': 'negative', 'score': 0.8042716979980469},
#  {'label': 'negative', 'score': 0.9528171420097351},
#  {'label': 'neutral', 'score': 0.5407333374023438},
#  {'label': 'negative', 'score': 0.5310109853744507},
#  {'label': 'neutral', 'score': 0.5719999670982361},
#  {'label': 'neutral', 'score': 0.6988736987113953},
#  {'label': 'neutral', 'score': 0.6916407942771912},
#  {'label': 'negative', 'score': 0.9181146621704102}]

# %%
sentiment_table = pd.DataFrame(sentiment_result)
sentiment_table
# Out:
#         label     score
# 0     neutral  0.912246
# 1     neutral  0.879370
# 2    positive  0.676261
# 3     neutral  0.925939
# 4     neutral  0.866223
# ..        ...       ...
# 995  negative  0.531011
# 996   neutral  0.572000
# 997   neutral  0.698874
# 998   neutral  0.691641
# 999  negative  0.918115
#
# [1000 rows x 2 columns]

# %% [markdown]
# Цикл для сентимент-анализа комментариев может работать довольно долго. Я крайне рекомендую вам переодически сохранять к себе на компьютер промежуточные результаты. Итоговый результат я рекомендую записать отдельным столбиком в таблицу с комментариями, а затем сохранить полученные результаты. 🤗🤗🤗

# %%
df_comments['sentiment_verdict'] = sentiment_table['label']
df_comments['sentiment_score'] = sentiment_table['score']

# <ваш код для сохранения данных>
df_comments.to_csv('sentiment_table.tsv')

# (your)my code here
# ¯\_(ツ)_/¯
df_comments.head()

# P.S. Код для скоринга комментариев работает довольно долго. Первый, кто проскорит всю базу, может поделиться ей в общем чате с однокурсниками
# Если вы используете эту базу, просто продемонстрируйте при решении этого пункта, что ваш код работает
# Out:
#            id     post_id             datetime  \
# 0  24006366.0  24006362.0  2019-02-01 23:14:14
# 1  24006370.0  24006362.0  2019-02-01 23:15:23
# 2  24006371.0  24006362.0  2019-02-01 23:16:21
# 3  24006374.0  24006362.0  2019-02-01 23:16:38
# 4  24006375.0  24006362.0  2019-02-01 23:16:40
#
#                                                 text  likes sentiment_verdict  \
# 0                                       ЧВК Вагнера?    5.0           neutral
# 1                [id4710641|Евгений], выздоравливай.    3.0           neutral
# 2  [id442655034|Андрей], искренне желаю этого все...    4.0          positive
# 3                         Опять про Украину новости?    1.0           neutral
# 4                                      Че такое ДНР?    2.0           neutral
#
#    sentiment_score
# 0         0.912246
# 1         0.879370
# 2         0.676261
# 3         0.925939
# 4         0.866223

# %%
# загрузка
sentiment_table_loaded = pd.read_csv('news_data/out.csv')
df_comments['sentiment_verdict'] = sentiment_table_loaded['label']
df_comments['sentiment_score'] = sentiment_table_loaded['score']
df_comments.head()
# Out:
#            id     post_id             datetime  \
# 0  24006366.0  24006362.0  2019-02-01 23:14:14
# 1  24006370.0  24006362.0  2019-02-01 23:15:23
# 2  24006371.0  24006362.0  2019-02-01 23:16:21
# 3  24006374.0  24006362.0  2019-02-01 23:16:38
# 4  24006375.0  24006362.0  2019-02-01 23:16:40
#
#                                                 text  likes sentiment_verdict  \
# 0                                       ЧВК Вагнера?    5.0           neutral
# 1                [id4710641|Евгений], выздоравливай.    3.0           neutral
# 2  [id442655034|Андрей], искренне желаю этого все...    4.0          positive
# 3                         Опять про Украину новости?    1.0           neutral
# 4                                      Че такое ДНР?    2.0           neutral
#
#    sentiment_score
# 0         0.912246
# 1         0.879370
# 2         0.676261
# 3         0.925939
# 4         0.866223

# %% [markdown]
# ## Часть 4: аналитика (1 балл + 0.2 бонусных)
#
# Мы с вами огромные молодцы. Мы обучили модель для категоризации новостей, построили с её помощью прогнозы. Мы проскорили комментарии на их сентимент-окрас. Теперь давайте проанализируем новости. Описывайте полученные результаты таким образом, чтобы не получить уголовку на 5 лет за дискредитацию чего-нибудь или оскорбление чувств кого-нибудь 💜

# %% [markdown]
# __[0.2 балла]__ Какая доля комментариев позитивная? Какая доля комментариев негативная? Выведите 10 самых позитивных комментариев.
#
# Выведите 10 самых негативных комментариев, поугарайте с них. Удалите их вывод из тетрадки. Никто не должен их видеть, это должно остаться только между нами. Поззитивные не удаляйте. Они пусть останутся.

# %%
# (your)my code here
# ʕ•ᴥ•ʔ
positive_ratio = (df_comments['sentiment_verdict'] == 'positive').sum() / df_comments.shape[0]
negative_ratio = (df_comments['sentiment_verdict'] == 'negative').sum() / df_comments.shape[0]
print(f'Позитивная доля = {positive_ratio}')
print(f'Негативная доля = {negative_ratio}')
# Out:
# Позитивная доля = 0.06954603964053067
# Негативная доля = 0.2209980827740946

# %%
print("Топ 10 позитивных")
df_comments[df_comments['sentiment_verdict'] == 'positive'].sort_values(by='sentiment_score', ascending=False)['text'].values.tolist()[:10]
# Out:
# Топ 10 позитивных
# ['По всем рсми рашки твердят что аналогов С400 нет, а тут заявляют что С400 дешевле аналогов ))) кто то обделался',
#  'Осталось за воздух взимать плату. Ждем-с',
#  '[id326530640|Без], эх, вот эти твои слова Владимир Владимирович прям дословно им высказал бы в лицо 😎😎😎',
#  '[id339999071|Костя], Блин, вы все время ждёте "какого-то ужаса", то после выборов в США, то после выборов у нас, то после ещё чего-то...А все норм. Причем в свете того, что Европа больше всего заинтересована в поставках газа из РФ рассматривать вариант, что Северный поток - 2, закроют в отместку глупо. Причем Германия за Северный поток, против хохлы, поляки, по моему здесь все ясно...',
#  'Отнял жизнь молодой девчонки. Такому не пожизненное надо а смерть через пыточную машину( чтоб людям не мараться). А девкам урок-нефиг находится одной без парня,брата и.тд в такой компании',
#  'А Путин  втер нам что  средний продолжительность жизни рос до 73 лет. А министры и депутаты почему то доказывают обратное.)))))',
#  'Вы депутатов деньги то не считайте!))))',
#  'Сказки про отказ от доллара продолжаются. Лапшу всем повесили.',
#  '[id114124060|Олег], русские долго запрягают,но быстро едут. Бисмарк. Россия это спящий гигант(будущий мировой лидер либертарианства - синоним цивилизации )',
#  'No bad']

# %%
print("Топ 10 негативных")
df_comments[df_comments['sentiment_verdict'] == 'negative'].sort_values(by='sentiment_score', ascending=False)['text'].values.tolist()[:10]

# %% [markdown]
# __[0.2 балла]__ Для каждой новости из датасета посчитайте количество негативных и позитивных комментариев под ней. Сохраните эти количества в виде новых колонок.

# %%
# (your)my code here
# [✖‿✖]
number_of_positive = df_comments[df_comments['sentiment_verdict'] == 'positive'].groupby('post_id')['sentiment_verdict'].count()
number_of_negative = df_comments[df_comments['sentiment_verdict'] == 'negative'].groupby('post_id')['sentiment_verdict'].count()
df_count_sentiment = pd.DataFrame({'number_of_positive' : number_of_positive, 'number_of_negative' : number_of_negative})
df_count_sentiment.head()
# Out:
#             number_of_positive  number_of_negative
# post_id
# 18223951.0                 9.0                56.0
# 18224542.0                 1.0                14.0
# 18224684.0                 2.0                12.0
# 18224973.0                 6.0                 7.0
# 18225324.0                12.0                54.0

# %% [markdown]
# __[0.2 балл]__ Правда ли, что новости с большим количеством лайков получают больше негативных комментариев? А позитивных? Правда ли, что чем больше лайков, тем под новостью больше комментариев?
#
# Постройте визуализацию, которая могла бы это проиллюстрировать.

# %%
# (your)my code here
# ┌(ಠ_ಠ)┘

# %% [markdown]
# __[0.2]__  Давайте построим по сентимент-окрасу комментариев топ позитивных новостей.
#
# - Если под новостью оставлено 100 комментариев, из которых 80 позитивные, мы можем быть уверены в том, что новость была хорошо воспринята людьми.
# - Если под новостью всего один комментарий и он оказался позитивным, то у нас 100% позитивных комментариев, но это вовсе не означает, что новость была воспринята хорошо.
#
# Получается, что сортировать по доле позитивных комментариев нельзя. Давайте поступим умнее. Доля позитивных комментариев под постом -- это случайная величина. Её довольно часто моделируют с помощью бета-распределения. Если это случайная величина, мы можем построить для неё предиктивный интервал. Пусть $u$ - число позитивных комментариев, а $d$ - нейтральных и негативных.  Пусть
#
# $$
# a = 1 + u \qquad b = 1 + d.
# $$
#
# Тогда нижняя граница $95\%$ предиктивного интервала для доли будет вычисляться по такой формуле:
#
# $$
# \frac{a}{a + b} - 1.65 \cdot \sqrt{\frac{a \cdot b}{(a + b)^2 \cdot (a + b + 1)}}
# $$
#
# Если под новостью был всего один комментарий, у такой случайной величины будет высокая дисперсия. Это означаen, что штука, которую мы вычитаем из доли, окажется высокой. Левая граница интервала окажется маленькой и мы не поднимем комментарий в нашем топе наверх. Фактически мы делаем сортировку по квантилю уровня $0.05$ вместо среднего.
#
# От вас требуется вбить эту формулу, сделать сортировку и вывести на экран топ позитивных новостей. Подробнее про то, откуда берётся эта формула можно почитать [в этой книге.](https://disk.yandex.ru/i/Ctd08bTwC9eI3g) Ищите 4 главу, страницу 140.

# %%
# (your)my code here
# ฅ^•ﻌ•^ฅ

# %% [markdown]
# Построили? Срочно пришлите свою любимую позитивную  новость в общий чат!!!
#
# Топ негативных новостей строить не будем. Вокруг итак слишком много негатива 😻😻😻

# %% [markdown]
# __[0.2]__ Какие категории новостей оказались самыми позитивными? Придумайте способ найти такие категории и опишите его тут.
#
# __Ответ:__

# %%
# (your)my code here
# ٩(⁎❛ᴗ❛⁎)۶

# %% [markdown]
# __[0.2 бонусных]__ Проанализируйте, как температура комментария (вероятность того, что он негативный) зависит от длины трэда (число комментариев под новостью)? Значима ли эта взаимосвязь? Если вам для проверки этого хочется построить линейную регрессию, не сдерживайтесь.

# %%
# your code here
# ヾ(๑╹◡╹)ﾉ
